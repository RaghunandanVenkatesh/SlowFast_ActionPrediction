# %% [markdown]
# For the video action recognition, we are using [**PySlowFast**](https://github.com/facebookresearch/SlowFast) from Facebook Research.
#
# The goal of PySlowFast is to provide a high-performance, light-weight pytorch codebase provides state-of-the-art video backbones for video understanding research on different tasks (classification, detection, and etc). It is designed in order to support rapid implementation and evaluation of novel video research ideas. PySlowFast includes implementations of the following backbone network architectures:
#
# - SlowFast
# - Slow
# - C2D
# - I3D
# - Non-local Network
# - X3D
# - MViTv1 and MViTv2
# - Rev-ViT and Rev-MViT
#
#
# We used SLOW network architecture for this competetion

# %% [markdown]
# We have done modifications required to the model and source code and created our own github repo. The link is [**here**](https://github.com/RaghunandanVenkatesh/SlowFast/tree/dphi).
#
#
# The required python module installations and dataset preparation is followed from the PySlowfast official github repo.
#
# The detailed explaination of custom dataset preparation can be seen [here](https://github.com/facebookresearch/SlowFast/issues/149#issuecomment-723265461)

# %% [markdown]
# PySlowfast project gives a lot of flexible features for training and testing, including saving the checkpoints, auto resume training, augmenting dataset, testing with a check point, write predictions to a text file. Each of these features are controlled using YAML files.
#
# The model parameters and custom configuration are written in Yaml files and added to our repository
#
# - Training Configuration [YAML](https://github.com/RaghunandanVenkatesh/SlowFast/blob/dphi/configs/MyData/SLOW_NLN_8x8_R50-Train.yaml)
# - Testing Configuration [YAML](https://github.com/RaghunandanVenkatesh/SlowFast/blob/dphi/configs/MyData/SLOW_NLN_8x8_R50-Test.yaml)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["CUDA_LAUNCH_BLOCKING"]="1"

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# !git clone https://github.com/RaghunandanVenkatesh/SlowFast

# %% [markdown]
# Follow installation instructions here [INSTALL.md](https://github.com/facebookresearch/SlowFast/blob/main/INSTALL.md)

# %%
% cd SlowFast

# %% [markdown]
# **Training on the dataset**

# %%
# !python tools/run_net.py --cfg configs/MyData/SLOW_NLN_8x8_R50-Train.yaml
# Out:
# /opt/conda/lib/python3.7/site-packages/torchvision/transforms/_functional_video.py:7: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   "The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. "
# /opt/conda/lib/python3.7/site-packages/torchvision/transforms/_transforms_video.py:23: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   "The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. "
# config files: ['configs/MyData/SLOW_NLN_8x8_R50.yaml']
# [11/28 05:34:21][INFO] train_net.py:  536: Train with config:
# [11/28 05:34:21][INFO] train_net.py:  537: {'AUG': {'AA_TYPE': 'rand-m9-mstd0.5-inc1',
#          'COLOR_JITTER': 0.4,
#          'ENABLE': False,
#          'GEN_MASK_LOADER': False,
#          'INTERPOLATION': 'bicubic',
#          'MASK_FRAMES': False,
#          'MASK_RATIO': 0.0,
#          'MASK_TUBE': False,
#          'MASK_WINDOW_SIZE': [8, 7, 7],
#          'MAX_MASK_PATCHES_PER_BLOCK': None,
#          'NUM_SAMPLE': 1,
#          'RE_COUNT': 1,
#          'RE_MODE': 'pixel',
#          'RE_PROB': 0.25,
#          'RE_SPLIT': False},
#  'AVA': {'ANNOTATION_DIR': '/mnt/vol/gfsai-flash3-east/ai-group/users/haoqifan/ava/frame_list/',
#          'BGR': False,
#          'DETECTION_SCORE_THRESH': 0.9,
#          'EXCLUSION_FILE': 'ava_val_excluded_timestamps_v2.2.csv',
#          'FRAME_DIR': '/mnt/fair-flash3-east/ava_trainval_frames.img/',
#          'FRAME_LIST_DIR': '/mnt/vol/gfsai-flash3-east/ai-group/users/haoqifan/ava/frame_list/',
#          'FULL_TEST_ON_VAL': False,
#          'GROUNDTRUTH_FILE': 'ava_val_v2.2.csv',
#          'IMG_PROC_BACKEND': 'cv2',
#          'LABEL_MAP_FILE': 'ava_action_list_v2.2_for_activitynet_2019.pbtxt',
#          'TEST_FORCE_FLIP': False,
#          'TEST_LISTS': ['val.csv'],
#          'TEST_PREDICT_BOX_LISTS': ['ava_val_predicted_boxes.csv'],
#          'TRAIN_GT_BOX_LISTS': ['ava_train_v2.2.csv'],
#          'TRAIN_LISTS': ['train.csv'],
#          'TRAIN_PCA_JITTER_ONLY': True,
#          'TRAIN_PREDICT_BOX_LISTS': [],
#          'TRAIN_USE_COLOR_AUGMENTATION': False},
#  'BENCHMARK': CfgNode({'NUM_EPOCHS': 5, 'LOG_PERIOD': 100, 'SHUFFLE': True}),
#  'BN': {'GLOBAL_SYNC': False,
#         'NORM_TYPE': 'batchnorm',
#         'NUM_BATCHES_PRECISE': 200,
#         'NUM_SPLITS': 1,
#         'NUM_SYNC_DEVICES': 1,
#         'USE_PRECISE_STATS': True,
#         'WEIGHT_DECAY': 0.0},
#  'CONTRASTIVE': {'BN_MLP': False,
#                  'BN_SYNC_MLP': False,
#                  'DELTA_CLIPS_MAX': inf,
#                  'DELTA_CLIPS_MIN': -inf,
#                  'DIM': 128,
#                  'INTERP_MEMORY': False,
#                  'KNN_ON': True,
#                  'LENGTH': 239975,
#                  'LOCAL_SHUFFLE_BN': True,
#                  'MEM_TYPE': '1d',
#                  'MLP_DIM': 2048,
#                  'MOCO_MULTI_VIEW_QUEUE': False,
#                  'MOMENTUM': 0.5,
#                  'MOMENTUM_ANNEALING': False,
#                  'NUM_CLASSES_DOWNSTREAM': 13,
#                  'NUM_MLP_LAYERS': 1,
#                  'PREDICTOR_DEPTHS': [],
#                  'QUEUE_LEN': 65536,
#                  'SEQUENTIAL': False,
#                  'SIMCLR_DIST_ON': True,
#                  'SWAV_QEUE_LEN': 0,
#                  'T': 0.07,
#                  'TYPE': 'mem'},
#  'DATA': {'COLOR_RND_GRAYSCALE': 0.0,
#           'DECODING_BACKEND': 'pyav',
#           'DECODING_SHORT_SIZE': 256,
#           'DUMMY_LOAD': False,
#           'ENSEMBLE_METHOD': 'sum',
#           'IN22K_TRAINVAL': False,
#           'IN22k_VAL_IN1K': '',
#           'INPUT_CHANNEL_NUM': [3],
#           'INV_UNIFORM_SAMPLE': False,
#           'IN_VAL_CROP_RATIO': 0.875,
#           'LOADER_CHUNK_OVERALL_SIZE': 0,
#           'LOADER_CHUNK_SIZE': 0,
#           'MEAN': [0.45, 0.45, 0.45],
#           'MULTI_LABEL': False,
#           'NUM_FRAMES': 8,
#           'PATH_LABEL_SEPARATOR': ' ',
#           'PATH_PREFIX': '',
#           'PATH_TO_DATA_DIR': '/workspace/slowfast/data/MyData',
#           'PATH_TO_PRELOAD_IMDB': '',
#           'RANDOM_FLIP': True,
#           'REVERSE_INPUT_CHANNEL': False,
#           'SAMPLING_RATE': 8,
#           'SKIP_ROWS': 0,
#           'SSL_BLUR_SIGMA_MAX': [0.0, 2.0],
#           'SSL_BLUR_SIGMA_MIN': [0.0, 0.1],
#           'SSL_COLOR_BRI_CON_SAT': [0.4, 0.4, 0.4],
#           'SSL_COLOR_HUE': 0.1,
#           'SSL_COLOR_JITTER': False,
#           'SSL_MOCOV2_AUG': False,
#           'STD': [0.225, 0.225, 0.225],
#           'TARGET_FPS': 30,
#           'TEST_CROP_SIZE': 256,
#           'TIME_DIFF_PROB': 0.0,
#           'TRAIN_CROP_NUM_SPATIAL': 1,
#           'TRAIN_CROP_NUM_TEMPORAL': 1,
#           'TRAIN_CROP_SIZE': 224,
#           'TRAIN_JITTER_ASPECT_RELATIVE': [],
#           'TRAIN_JITTER_FPS': 0.0,
#           'TRAIN_JITTER_MOTION_SHIFT': False,
#           'TRAIN_JITTER_SCALES': [256, 320],
#           'TRAIN_JITTER_SCALES_RELATIVE': [],
#           'TRAIN_PCA_EIGVAL': [0.225, 0.224, 0.229],
#           'TRAIN_PCA_EIGVEC': [[-0.5675, 0.7192, 0.4009],
#                                [-0.5808, -0.0045, -0.814],
#                                [-0.5836, -0.6948, 0.4203]],
#           'USE_OFFSET_SAMPLING': False},
#  'DATA_LOADER': {'ENABLE_MULTI_THREAD_DECODE': False,
#                  'NUM_WORKERS': 4,
#                  'PIN_MEMORY': True},
#  'DEMO': {'BUFFER_SIZE': 0,
#           'CLIP_VIS_SIZE': 10,
#           'COMMON_CLASS_NAMES': ['watch (a person)',
#                                  'talk to (e.g., self, a person, a group)',
#                                  'listen to (a person)',
#                                  'touch (an object)',
#                                  'carry/hold (an object)',
#                                  'walk',
#                                  'sit',
#                                  'lie/sleep',
#                                  'bend/bow (at the waist)'],
#           'COMMON_CLASS_THRES': 0.25,
#           'DETECTRON2_CFG': 'COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml',
#           'DETECTRON2_THRESH': 0.9,
#           'DETECTRON2_WEIGHTS': 'detectron2://COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl',
#           'DISPLAY_HEIGHT': 0,
#           'DISPLAY_WIDTH': 0,
#           'ENABLE': False,
#           'FPS': 30,
#           'GT_BOXES': '',
#           'INPUT_FORMAT': 'BGR',
#           'INPUT_VIDEO': '/workspace/slowfast/data/MyData/Abuse/Abuse001_x264.mp4',
#           'LABEL_FILE_PATH': '/workspace/slowfast/data/MyData/classids.json',
#           'NUM_CLIPS_SKIP': 0,
#           'NUM_VIS_INSTANCES': 2,
#           'OUTPUT_FILE': '/workspace/slowfast/data/MyData/output.mp4',
#           'OUTPUT_FPS': -1,
#           'PREDS_BOXES': '',
#           'SLOWMO': 1,
#           'STARTING_SECOND': 900,
#           'THREAD_ENABLE': False,
#           'UNCOMMON_CLASS_THRES': 0.3,
#           'VIS_MODE': 'thres',
#           'WEBCAM': -1},
#  'DETECTION': {'ALIGNED': True,
#                'ENABLE': False,
#                'ROI_XFORM_RESOLUTION': 7,
#                'SPATIAL_SCALE_FACTOR': 16},
#  'DIST_BACKEND': 'nccl',
#  'LOG_MODEL_INFO': True,
#  'LOG_PERIOD': 10,
#  'MASK': {'DECODER_DEPTH': 0,
#           'DECODER_EMBED_DIM': 512,
#           'DECODER_SEP_POS_EMBED': False,
#           'DEC_KV_KERNEL': [],
#           'DEC_KV_STRIDE': [],
#           'ENABLE': False,
#           'HEAD_TYPE': 'separate',
#           'MAE_ON': False,
#           'MAE_RND_MASK': False,
#           'NORM_PRED_PIXEL': True,
#           'PER_FRAME_MASKING': False,
#           'PRED_HOG': False,
#           'PRETRAIN_DEPTH': [15],
#           'SCALE_INIT_BY_DEPTH': False,
#           'TIME_STRIDE_LOSS': True},
#  'MIXUP': {'ALPHA': 0.8,
#            'CUTMIX_ALPHA': 1.0,
#            'ENABLE': False,
#            'LABEL_SMOOTH_VALUE': 0.1,
#            'PROB': 1.0,
#            'SWITCH_PROB': 0.5},
#  'MODEL': {'ACT_CHECKPOINT': False,
#            'ARCH': 'slow',
#            'DETACH_FINAL_FC': False,
#            'DROPCONNECT_RATE': 0.0,
#            'DROPOUT_RATE': 0.5,
#            'FC_INIT_STD': 0.01,
#            'FP16_ALLREDUCE': False,
#            'FROZEN_BN': False,
#            'HEAD_ACT': 'softmax',
#            'LOSS_FUNC': 'cross_entropy',
#            'MODEL_NAME': 'ResNet',
#            'MULTI_PATHWAY_ARCH': ['slowfast'],
#            'NUM_CLASSES': 7,
#            'SINGLE_PATHWAY_ARCH': ['2d',
#                                    'c2d',
#                                    'i3d',
#                                    'slow',
#                                    'x3d',
#                                    'mvit',
#                                    'maskmvit']},
#  'MULTIGRID': {'BN_BASE_SIZE': 8,
#                'DEFAULT_B': 0,
#                'DEFAULT_S': 0,
#                'DEFAULT_T': 0,
#                'EPOCH_FACTOR': 1.5,
#                'EVAL_FREQ': 3,
#                'LONG_CYCLE': False,
#                'LONG_CYCLE_FACTORS': [(0.25, 0.7071067811865476),
#                                       (0.5, 0.7071067811865476),
#                                       (0.5, 1),
#                                       (1, 1)],
#                'LONG_CYCLE_SAMPLING_RATE': 0,
#                'SHORT_CYCLE': False,
#                'SHORT_CYCLE_FACTORS': [0.5, 0.7071067811865476]},
#  'MVIT': {'CLS_EMBED_ON': True,
#           'DEPTH': 16,
#           'DIM_MUL': [],
#           'DIM_MUL_IN_ATT': False,
#           'DROPOUT_RATE': 0.0,
#           'DROPPATH_RATE': 0.1,
#           'EMBED_DIM': 96,
#           'HEAD_INIT_SCALE': 1.0,
#           'HEAD_MUL': [],
#           'LAYER_SCALE_INIT_VALUE': 0.0,
#           'MLP_RATIO': 4.0,
#           'MODE': 'conv',
#           'NORM': 'layernorm',
#           'NORM_STEM': False,
#           'NUM_HEADS': 1,
#           'PATCH_2D': False,
#           'PATCH_KERNEL': [3, 7, 7],
#           'PATCH_PADDING': [2, 4, 4],
#           'PATCH_STRIDE': [2, 4, 4],
#           'POOL_FIRST': False,
#           'POOL_KVQ_KERNEL': None,
#           'POOL_KV_STRIDE': [],
#           'POOL_KV_STRIDE_ADAPTIVE': None,
#           'POOL_Q_STRIDE': [],
#           'QKV_BIAS': True,
#           'REL_POS_SPATIAL': False,
#           'REL_POS_TEMPORAL': False,
#           'REL_POS_ZERO_INIT': False,
#           'RESIDUAL_POOLING': False,
#           'REV': {'BUFFER_LAYERS': [],
#                   'ENABLE': False,
#                   'PRE_Q_FUSION': 'avg',
#                   'RESPATH_FUSE': 'concat',
#                   'RES_PATH': 'conv'},
#           'SEPARATE_QKV': False,
#           'SEP_POS_EMBED': False,
#           'USE_ABS_POS': True,
#           'USE_FIXED_SINCOS_POS': False,
#           'USE_MEAN_POOLING': False,
#           'ZERO_DECAY_POS_CLS': True},
#  'NONLOCAL': {'GROUP': [[1], [1], [1], [1]],
#               'INSTANTIATION': 'dot_product',
#               'LOCATION': [[[]], [[1, 3]], [[1, 3, 5]], [[]]],
#               'POOL': [[[1, 2, 2], [1, 2, 2]],
#                        [[1, 2, 2], [1, 2, 2]],
#                        [[1, 2, 2], [1, 2, 2]],
#                        [[1, 2, 2], [1, 2, 2]]]},
#  'NUM_GPUS': 1,
#  'NUM_SHARDS': 1,
#  'OUTPUT_DIR': '.',
#  'RESNET': {'DEPTH': 50,
#             'INPLACE_RELU': True,
#             'NUM_BLOCK_TEMP_KERNEL': [[3], [4], [6], [3]],
#             'NUM_GROUPS': 1,
#             'SPATIAL_DILATIONS': [[1], [1], [1], [1]],
#             'SPATIAL_STRIDES': [[1], [2], [2], [2]],
#             'STRIDE_1X1': False,
#             'TRANS_FUNC': 'bottleneck_transform',
#             'WIDTH_PER_GROUP': 64,
#             'ZERO_INIT_FINAL_BN': True,
#             'ZERO_INIT_FINAL_CONV': False},
#  'RNG_SEED': 0,
#  'SHARD_ID': 0,
#  'SLOWFAST': {'ALPHA': 8,
#               'BETA_INV': 8,
#               'FUSION_CONV_CHANNEL_RATIO': 2,
#               'FUSION_KERNEL_SZ': 5},
#  'SOLVER': {'BASE_LR': 0.1,
#             'BASE_LR_SCALE_NUM_SHARDS': False,
#             'BETAS': (0.9, 0.999),
#             'CLIP_GRAD_L2NORM': None,
#             'CLIP_GRAD_VAL': None,
#             'COSINE_AFTER_WARMUP': False,
#             'COSINE_END_LR': 0.0,
#             'DAMPENING': 0.0,
#             'GAMMA': 0.1,
#             'LARS_ON': False,
#             'LAYER_DECAY': 1.0,
#             'LRS': [],
#             'LR_POLICY': 'cosine',
#             'MAX_EPOCH': 200,
#             'MOMENTUM': 0.9,
#             'NESTEROV': True,
#             'OPTIMIZING_METHOD': 'sgd',
#             'STEPS': [],
#             'STEP_SIZE': 1,
#             'WARMUP_EPOCHS': 34.0,
#             'WARMUP_FACTOR': 0.1,
#             'WARMUP_START_LR': 0.01,
#             'WEIGHT_DECAY': 0.0001,
#             'ZERO_WD_1D_PARAM': False},
#  'TASK': '',
#  'TENSORBOARD': {'CATEGORIES_PATH': '',
#                  'CLASS_NAMES_PATH': '/workspace/slowfast/data/MyData/classids.json',
#                  'CONFUSION_MATRIX': {'ENABLE': False,
#                                       'FIGSIZE': [8, 8],
#                                       'SUBSET_PATH': ''},
#                  'ENABLE': True,
#                  'HISTOGRAM': {'ENABLE': False,
#                                'FIGSIZE': [8, 8],
#                                'SUBSET_PATH': '',
#                                'TOPK': 10},
#                  'LOG_DIR': '',
#                  'MODEL_VIS': {'ACTIVATIONS': False,
#                                'COLORMAP': 'Pastel2',
#                                'ENABLE': False,
#                                'GRAD_CAM': {'COLORMAP': 'viridis',
#                                             'ENABLE': True,
#                                             'LAYER_LIST': [],
#                                             'USE_TRUE_LABEL': False},
#                                'INPUT_VIDEO': False,
#                                'LAYER_LIST': [],
#                                'MODEL_WEIGHTS': False,
#                                'TOPK_PREDS': 1},
#                  'PREDICTIONS_PATH': '',
#                  'WRONG_PRED_VIS': {'ENABLE': False,
#                                     'SUBSET_PATH': '',
#                                     'TAG': 'Incorrectly classified videos.'}},
#  'TEST': {'BATCH_SIZE': 16,
#           'CHECKPOINT_FILE_PATH': '/workspace/slowfast/checkpoints/checkpoint_epoch_00160.pyth',
#           'CHECKPOINT_TYPE': 'pytorch',
#           'DATASET': 'mydata',
#           'ENABLE': False,
#           'NUM_ENSEMBLE_VIEWS': 10,
#           'NUM_SPATIAL_CROPS': 3,
#           'NUM_TEMPORAL_CLIPS': [],
#           'SAVE_RESULTS_PATH': 'output1.pkl'},
#  'TRAIN': {'AUTO_RESUME': True,
#            'BATCH_SIZE': 16,
#            'CHECKPOINT_CLEAR_NAME_PATTERN': (),
#            'CHECKPOINT_EPOCH_RESET': False,
#            'CHECKPOINT_FILE_PATH': '',
#            'CHECKPOINT_INFLATE': False,
#            'CHECKPOINT_IN_INIT': False,
#            'CHECKPOINT_PERIOD': 1,
#            'CHECKPOINT_TYPE': 'pytorch',
#            'DATASET': 'mydata',
#            'ENABLE': True,
#            'EVAL_PERIOD': 20,
#            'KILL_LOSS_EXPLOSION_FACTOR': 0.0,
#            'MIXED_PRECISION': False},
#  'VIS_MASK': CfgNode({'ENABLE': False}),
#  'X3D': {'BN_LIN5': False,
#          'BOTTLENECK_FACTOR': 1.0,
#          'CHANNELWISE_3x3x3': True,
#          'DEPTH_FACTOR': 1.0,
#          'DIM_C1': 12,
#          'DIM_C5': 2048,
#          'SCALE_RES2': False,
#          'WIDTH_FACTOR': 1.0}}
# [11/28 05:34:23][INFO] misc.py:  185: Model:
# ResNet(
#   (s1): VideoModelStem(
#     (pathway0_stem): ResNetBasicStem(
#       (conv): Conv3d(3, 64, kernel_size=(1, 7, 7), stride=(1, 2, 2), padding=(0, 3, 3), bias=False)
#       (bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (pool_layer): MaxPool3d(kernel_size=[1, 3, 3], stride=[1, 2, 2], padding=[0, 1, 1], dilation=1, ceil_mode=False)
#     )
#   )
#   (s2): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (branch1_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (pathway0_pool): MaxPool3d(kernel_size=[1, 1, 1], stride=[1, 1, 1], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#   (s3): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal1): Nonlocal(
#       (conv_theta): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res3): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal3): Nonlocal(
#       (conv_theta): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#   )
#   (s4): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal1): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res3): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal3): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res4): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res5): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal5): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#   )
#   (s5): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (head): ResNetBasicHead(
#     (predictors): ModuleList()
#     (pathway0_avgpool): AvgPool3d(kernel_size=[8, 7, 7], stride=1, padding=0)
#     (dropout): Dropout(p=0.5, inplace=False)
#     (projection): Linear(in_features=2048, out_features=7, bias=True)
#     (act): Softmax(dim=4)
#   )
# )
# [11/28 05:34:23][INFO] misc.py:  187: Params: 39,007,303
# [11/28 05:34:23][INFO] misc.py:  188: Mem: 0.14655351638793945 MB
# [11/28 05:34:24][WARNING] jit_analysis.py:  500: Unsupported operator aten::max_pool3d encountered 7 time(s)
# [11/28 05:34:24][WARNING] jit_analysis.py:  500: Unsupported operator aten::add encountered 21 time(s)
# [11/28 05:34:24][WARNING] jit_analysis.py:  500: Unsupported operator aten::div encountered 5 time(s)
# [11/28 05:34:24][WARNING] jit_analysis.py:  500: Unsupported operator aten::avg_pool3d encountered 1 time(s)
# [11/28 05:34:24][WARNING] jit_analysis.py:  500: Unsupported operator aten::softmax encountered 1 time(s)
# [11/28 05:34:24][INFO] misc.py:  190: Flops: 64.17511833600001 G
# [11/28 05:34:25][WARNING] jit_analysis.py:  500: Unsupported operator aten::batch_norm encountered 58 time(s)
# [11/28 05:34:25][WARNING] jit_analysis.py:  500: Unsupported operator aten::max_pool3d encountered 7 time(s)
# [11/28 05:34:25][WARNING] jit_analysis.py:  500: Unsupported operator aten::add encountered 21 time(s)
# [11/28 05:34:25][WARNING] jit_analysis.py:  500: Unsupported operator aten::div encountered 5 time(s)
# [11/28 05:34:25][WARNING] jit_analysis.py:  500: Unsupported operator aten::avg_pool3d encountered 1 time(s)
# [11/28 05:34:25][WARNING] jit_analysis.py:  500: Unsupported operator aten::softmax encountered 1 time(s)
# [11/28 05:34:25][INFO] misc.py:  193: Activations: 135.71354300000002 M
# [11/28 05:34:25][INFO] misc.py:  196: nvidia-smi
# Mon Nov 28 05:34:25 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.141.03   Driver Version: 470.141.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A10G         Off  | 00000000:00:1E.0 Off |                    0 |
# |  0%   22C    P0    62W / 300W |   2729MiB / 22731MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# bn 116, non bn 95, zero 0, no grad 0
# [11/28 05:34:25][INFO] train_net.py:  552: Load from last checkpoint.
# [11/28 05:34:25][INFO] checkpoint.py:  222: Loading network weights from ./checkpoints/checkpoint_epoch_00004.pyth.
# missing keys: []
# unexpected keys: []
# [11/28 05:34:25][INFO] mydata.py:   93: Constructing Mydata train...
# [11/28 05:34:25][INFO] mydata.py:  160: Constructing kinetics dataloader (size: 950 skip_rows 0) from /workspace/slowfast/data/MyData/train.csv
# [11/28 05:34:25][INFO] mydata.py:   93: Constructing Mydata val...
# [11/28 05:34:25][INFO] mydata.py:  160: Constructing kinetics dataloader (size: 303 skip_rows 0) from /workspace/slowfast/data/MyData/val.csv
# [11/28 05:34:25][INFO] mydata.py:   93: Constructing Mydata train...
# [11/28 05:34:25][INFO] mydata.py:  160: Constructing kinetics dataloader (size: 950 skip_rows 0) from /workspace/slowfast/data/MyData/train.csv
# [11/28 05:34:25][DEBUG] tpu_cluster_resolver.py:   35: Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# [11/28 05:34:26][INFO] tensorboard_vis.py:   57: To see logged results in Tensorboard, please launch using the command             `tensorboard  --port=<port-number> --logdir ./runs-mydata`
# [11/28 05:34:26][INFO] train_net.py:  631: Start epoch: 5
# [11/28 05:34:35][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.71217, "dt_data": 0.00051, "dt_net": 0.71167, "epoch": "5/200", "eta": "2:17:08", "gpu_mem": "15.89G", "grad_norm": 2.08405, "iter": "10/59", "loss": 0.11194, "lr": 0.02014, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 05:34:42][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70989, "dt_data": 0.00060, "dt_net": 0.70929, "epoch": "5/200", "eta": "2:16:35", "gpu_mem": "15.89G", "grad_norm": 0.34567, "iter": "20/59", "loss": 0.06204, "lr": 0.02056, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 05:34:49][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.71076, "dt_data": 0.00080, "dt_net": 0.70997, "epoch": "5/200", "eta": "2:16:37", "gpu_mem": "15.89G", "grad_norm": 1.95425, "iter": "30/59", "loss": 0.07193, "lr": 0.02097, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 05:34:56][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70807, "dt_data": 0.00056, "dt_net": 0.70751, "epoch": "5/200", "eta": "2:15:59", "gpu_mem": "15.89G", "grad_norm": 3.03342, "iter": "40/59", "loss": 0.12301, "lr": 0.02138, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 05:35:03][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.71123, "dt_data": 0.00075, "dt_net": 0.71048, "epoch": "5/200", "eta": "2:16:29", "gpu_mem": "15.89G", "grad_norm": 3.57733, "iter": "50/59", "loss": 0.06322, "lr": 0.02180, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 05:35:10][INFO] logging.py:   99: json_stats: {"RAM": "8.68/62.13G", "_type": "train_epoch", "dt": 0.19658, "dt_data": 0.19658, "dt_net": 0.70537, "epoch": "5/200", "eta": "0:37:41", "gpu_mem": "15.89G", "grad_norm": 5.63498, "loss": 0.13271, "lr": 0.02217, "top1_err": 3.81356, "top5_err": 0.21186}
# [11/28 05:35:10][INFO] train_net.py:  693: Epoch 4 takes 43.67s. Epochs from 4 to 4 take 43.67s in average and 43.67s in median.
# [11/28 05:35:10][INFO] train_net.py:  699: For epoch 4, each iteraction takes 0.74s in average. From epoch 4 to 4, each iteraction takes 0.74s in average.
# [11/28 05:35:10][INFO] precise_bn.py:  129: Computing precise BN statistics for 58 BN layers ...
# [11/28 05:35:34][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70525, "dt_data": 0.00055, "dt_net": 0.70471, "epoch": "6/200", "eta": "2:15:06", "gpu_mem": "15.89G", "grad_norm": 15.08759, "iter": "10/59", "loss": 3.82825, "lr": 0.02258, "top1_err": 68.75000, "top5_err": 15.62500}
# [11/28 05:35:41][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70498, "dt_data": 0.00060, "dt_net": 0.70438, "epoch": "6/200", "eta": "2:14:56", "gpu_mem": "15.89G", "grad_norm": 13.27915, "iter": "20/59", "loss": 3.96713, "lr": 0.02300, "top1_err": 68.75000, "top5_err": 21.87500}
# [11/28 05:35:48][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70502, "dt_data": 0.00063, "dt_net": 0.70438, "epoch": "6/200", "eta": "2:14:50", "gpu_mem": "15.89G", "grad_norm": 10.92185, "iter": "30/59", "loss": 4.04362, "lr": 0.02341, "top1_err": 81.25000, "top5_err": 18.75000}
# [11/28 05:35:55][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70449, "dt_data": 0.00060, "dt_net": 0.70390, "epoch": "6/200", "eta": "2:14:37", "gpu_mem": "15.89G", "grad_norm": 7.85471, "iter": "40/59", "loss": 3.72749, "lr": 0.02383, "top1_err": 78.12500, "top5_err": 21.87500}
# [11/28 05:36:02][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70953, "dt_data": 0.00052, "dt_net": 0.70901, "epoch": "6/200", "eta": "2:15:27", "gpu_mem": "15.89G", "grad_norm": 5.28470, "iter": "50/59", "loss": 3.37880, "lr": 0.02424, "top1_err": 62.50000, "top5_err": 18.75000}
# [11/28 05:36:09][INFO] logging.py:   99: json_stats: {"RAM": "8.70/62.13G", "_type": "train_epoch", "dt": 0.19112, "dt_data": 0.19112, "dt_net": 0.70481, "epoch": "6/200", "eta": "0:36:27", "gpu_mem": "15.89G", "grad_norm": 8.51454, "loss": 3.70578, "lr": 0.02461, "top1_err": 71.18644, "top5_err": 20.65678}
# [11/28 05:36:09][INFO] train_net.py:  693: Epoch 5 takes 42.97s. Epochs from 4 to 5 take 43.32s in average and 43.32s in median.
# [11/28 05:36:09][INFO] train_net.py:  699: For epoch 5, each iteraction takes 0.73s in average. From epoch 4 to 5, each iteraction takes 0.73s in average.
# [11/28 05:36:09][INFO] precise_bn.py:  129: Computing precise BN statistics for 58 BN layers ...
# [11/28 05:36:33][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70490, "dt_data": 0.00051, "dt_net": 0.70439, "epoch": "7/200", "eta": "2:14:21", "gpu_mem": "15.89G", "grad_norm": 6.52168, "iter": "10/59", "loss": 2.34642, "lr": 0.02503, "top1_err": 68.75000, "top5_err": 18.75000}
# [11/28 05:36:40][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70467, "dt_data": 0.00056, "dt_net": 0.70412, "epoch": "7/200", "eta": "2:14:11", "gpu_mem": "15.89G", "grad_norm": 7.40653, "iter": "20/59", "loss": 2.42849, "lr": 0.02544, "top1_err": 71.87500, "top5_err": 15.62500}
# [11/28 05:36:47][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70481, "dt_data": 0.00056, "dt_net": 0.70425, "epoch": "7/200", "eta": "2:14:06", "gpu_mem": "15.89G", "grad_norm": 7.95979, "iter": "30/59", "loss": 2.25029, "lr": 0.02585, "top1_err": 68.75000, "top5_err": 18.75000}
# [11/28 05:36:54][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70606, "dt_data": 0.00068, "dt_net": 0.70538, "epoch": "7/200", "eta": "2:14:13", "gpu_mem": "15.89G", "grad_norm": 5.23536, "iter": "40/59", "loss": 2.30858, "lr": 0.02627, "top1_err": 62.50000, "top5_err": 25.00000}
# [11/28 05:37:01][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70839, "dt_data": 0.00055, "dt_net": 0.70783, "epoch": "7/200", "eta": "2:14:32", "gpu_mem": "15.89G", "grad_norm": 6.12085, "iter": "50/59", "loss": 2.06683, "lr": 0.02668, "top1_err": 68.75000, "top5_err": 12.50000}
# [11/28 05:37:08][INFO] logging.py:   99: json_stats: {"RAM": "8.68/62.13G", "_type": "train_epoch", "dt": 0.19368, "dt_data": 0.19368, "dt_net": 0.70358, "epoch": "7/200", "eta": "0:36:45", "gpu_mem": "15.89G", "grad_norm": 3.68878, "loss": 2.33858, "lr": 0.02705, "top1_err": 67.26695, "top5_err": 17.47881}
# [11/28 05:37:08][INFO] train_net.py:  693: Epoch 6 takes 42.94s. Epochs from 4 to 6 take 43.19s in average and 42.97s in median.
# [11/28 05:37:08][INFO] train_net.py:  699: For epoch 6, each iteraction takes 0.73s in average. From epoch 4 to 6, each iteraction takes 0.73s in average.
# [11/28 05:37:08][INFO] precise_bn.py:  129: Computing precise BN statistics for 58 BN layers ...
# [11/28 05:37:32][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.71017, "dt_data": 0.00074, "dt_net": 0.70942, "epoch": "8/200", "eta": "2:14:39", "gpu_mem": "15.89G", "grad_norm": 6.06296, "iter": "10/59", "loss": 2.14278, "lr": 0.02747, "top1_err": 68.75000, "top5_err": 15.62500}
# [11/28 05:37:39][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70347, "dt_data": 0.00063, "dt_net": 0.70284, "epoch": "8/200", "eta": "2:13:16", "gpu_mem": "15.89G", "grad_norm": 4.55005, "iter": "20/59", "loss": 2.15959, "lr": 0.02788, "top1_err": 50.00000, "top5_err": 15.62500}
# [11/28 05:37:46][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70786, "dt_data": 0.00069, "dt_net": 0.70717, "epoch": "8/200", "eta": "2:13:59", "gpu_mem": "15.89G", "grad_norm": 3.06535, "iter": "30/59", "loss": 1.89668, "lr": 0.02830, "top1_err": 59.37500, "top5_err": 12.50000}
# [11/28 05:37:53][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70465, "dt_data": 0.00068, "dt_net": 0.70398, "epoch": "8/200", "eta": "2:13:15", "gpu_mem": "15.89G", "grad_norm": 2.55791, "iter": "40/59", "loss": 1.99991, "lr": 0.02871, "top1_err": 68.75000, "top5_err": 12.50000}
# [11/28 05:38:00][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70918, "dt_data": 0.00076, "dt_net": 0.70842, "epoch": "8/200", "eta": "2:13:59", "gpu_mem": "15.89G", "grad_norm": 3.79046, "iter": "50/59", "loss": 1.81857, "lr": 0.02912, "top1_err": 62.50000, "top5_err": 12.50000}
# [11/28 05:38:07][INFO] logging.py:   99: json_stats: {"RAM": "8.69/62.13G", "_type": "train_epoch", "dt": 0.20121, "dt_data": 0.20121, "dt_net": 0.70328, "epoch": "8/200", "eta": "0:37:58", "gpu_mem": "15.89G", "grad_norm": 2.80222, "loss": 2.04813, "lr": 0.02950, "top1_err": 63.98305, "top5_err": 13.66525}
# [11/28 05:38:07][INFO] train_net.py:  693: Epoch 7 takes 42.96s. Epochs from 4 to 7 take 43.14s in average and 42.96s in median.
# [11/28 05:38:07][INFO] train_net.py:  699: For epoch 7, each iteraction takes 0.73s in average. From epoch 4 to 7, each iteraction takes 0.73s in average.
# [11/28 05:38:07][INFO] precise_bn.py:  129: Computing precise BN statistics for 58 BN layers ...
# [11/28 05:38:31][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70807, "dt_data": 0.00060, "dt_net": 0.70747, "epoch": "9/200", "eta": "2:13:33", "gpu_mem": "15.89G", "grad_norm": 2.45945, "iter": "10/59", "loss": 2.14852, "lr": 0.02991, "top1_err": 68.75000, "top5_err": 12.50000}
# [11/28 05:38:38][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70411, "dt_data": 0.00069, "dt_net": 0.70342, "epoch": "9/200", "eta": "2:12:42", "gpu_mem": "15.89G", "grad_norm": 3.33182, "iter": "20/59", "loss": 1.90760, "lr": 0.03032, "top1_err": 62.50000, "top5_err": 12.50000}
# [11/28 05:38:45][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70800, "dt_data": 0.00072, "dt_net": 0.70728, "epoch": "9/200", "eta": "2:13:19", "gpu_mem": "15.89G", "grad_norm": 3.95916, "iter": "30/59", "loss": 1.77056, "lr": 0.03074, "top1_err": 56.25000, "top5_err": 6.25000}
# [11/28 05:38:52][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70516, "dt_data": 0.00055, "dt_net": 0.70461, "epoch": "9/200", "eta": "2:12:39", "gpu_mem": "15.89G", "grad_norm": 4.29051, "iter": "40/59", "loss": 2.23867, "lr": 0.03115, "top1_err": 68.75000, "top5_err": 15.62500}
# [11/28 05:38:59][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70423, "dt_data": 0.00053, "dt_net": 0.70371, "epoch": "9/200", "eta": "2:12:22", "gpu_mem": "15.89G", "grad_norm": 4.37259, "iter": "50/59", "loss": 1.80205, "lr": 0.03157, "top1_err": 68.75000, "top5_err": 12.50000}
# [11/28 05:39:06][INFO] logging.py:   99: json_stats: {"RAM": "8.69/62.13G", "_type": "train_epoch", "dt": 0.19102, "dt_data": 0.19102, "dt_net": 0.70355, "epoch": "9/200", "eta": "0:35:52", "gpu_mem": "15.89G", "grad_norm": 3.01409, "loss": 2.03840, "lr": 0.03194, "top1_err": 63.13559, "top5_err": 13.98305}
# [11/28 05:39:06][INFO] train_net.py:  693: Epoch 8 takes 42.92s. Epochs from 4 to 8 take 43.09s in average and 42.96s in median.
# [11/28 05:39:06][INFO] train_net.py:  699: For epoch 8, each iteraction takes 0.73s in average. From epoch 4 to 8, each iteraction takes 0.73s in average.
# [11/28 05:39:06][INFO] precise_bn.py:  129: Computing precise BN statistics for 58 BN layers ...
# [11/28 05:39:30][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70958, "dt_data": 0.00057, "dt_net": 0.70901, "epoch": "10/200", "eta": "2:13:09", "gpu_mem": "15.89G", "grad_norm": 1.49319, "iter": "10/59", "loss": 1.83685, "lr": 0.03235, "top1_err": 59.37500, "top5_err": 12.50000}
# [11/28 05:39:37][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70271, "dt_data": 0.00054, "dt_net": 0.70217, "epoch": "10/200", "eta": "2:11:44", "gpu_mem": "15.89G", "grad_norm": 2.59390, "iter": "20/59", "loss": 1.93142, "lr": 0.03277, "top1_err": 68.75000, "top5_err": 9.37500}
# [11/28 05:39:44][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70320, "dt_data": 0.00061, "dt_net": 0.70259, "epoch": "10/200", "eta": "2:11:43", "gpu_mem": "15.89G", "grad_norm": 2.85227, "iter": "30/59", "loss": 1.67637, "lr": 0.03318, "top1_err": 56.25000, "top5_err": 9.37500}
# ...
# [11/28 08:41:58][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70998, "dt_data": 0.00056, "dt_net": 0.70941, "epoch": "194/200", "eta": "0:04:39", "gpu_mem": "15.89G", "grad_norm": 1.61418, "iter": "20/59", "loss": 0.06152, "lr": 0.00027, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:42:05][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70485, "dt_data": 0.00054, "dt_net": 0.70431, "epoch": "194/200", "eta": "0:04:29", "gpu_mem": "15.89G", "grad_norm": 0.91132, "iter": "30/59", "loss": 0.02321, "lr": 0.00026, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:42:13][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.71505, "dt_data": 0.00078, "dt_net": 0.71427, "epoch": "194/200", "eta": "0:04:26", "gpu_mem": "15.89G", "grad_norm": 1.27256, "iter": "40/59", "loss": 0.06986, "lr": 0.00025, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:42:20][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70943, "dt_data": 0.00055, "dt_net": 0.70888, "epoch": "194/200", "eta": "0:04:17", "gpu_mem": "15.89G", "grad_norm": 4.51392, "iter": "50/59", "loss": 0.03447, "lr": 0.00023, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:42:26][INFO] logging.py:   99: json_stats: {"RAM": "8.70/62.13G", "_type": "train_epoch", "dt": 0.19800, "dt_data": 0.19800, "dt_net": 0.70355, "epoch": "194/200", "eta": "0:01:10", "gpu_mem": "15.89G", "grad_norm": 0.50564, "loss": 0.07699, "lr": 0.00022, "top1_err": 2.11864, "top5_err": 0.00000}
# [11/28 08:42:26][INFO] train_net.py:  693: Epoch 193 takes 43.09s. Epochs from 4 to 193 take 43.01s in average and 43.01s in median.
# [11/28 08:42:26][INFO] train_net.py:  699: For epoch 193, each iteraction takes 0.73s in average. From epoch 4 to 193, each iteraction takes 0.73s in average.
# [11/28 08:42:26][INFO] precise_bn.py:  129: Computing precise BN statistics for 58 BN layers ...
# [11/28 08:42:50][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.71104, "dt_data": 0.00076, "dt_net": 0.71028, "epoch": "195/200", "eta": "0:04:04", "gpu_mem": "15.89G", "grad_norm": 5.81841, "iter": "10/59", "loss": 0.05956, "lr": 0.00021, "top1_err": 3.12500, "top5_err": 0.00000}
# [11/28 08:42:58][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70598, "dt_data": 0.00068, "dt_net": 0.70529, "epoch": "195/200", "eta": "0:03:55", "gpu_mem": "15.89G", "grad_norm": 2.23524, "iter": "20/59", "loss": 0.02429, "lr": 0.00020, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:43:05][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70437, "dt_data": 0.00051, "dt_net": 0.70386, "epoch": "195/200", "eta": "0:03:48", "gpu_mem": "15.89G", "grad_norm": 2.90839, "iter": "30/59", "loss": 0.04930, "lr": 0.00019, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:43:12][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70877, "dt_data": 0.00065, "dt_net": 0.70813, "epoch": "195/200", "eta": "0:03:42", "gpu_mem": "15.89G", "grad_norm": 3.60226, "iter": "40/59", "loss": 0.06934, "lr": 0.00018, "top1_err": 3.12500, "top5_err": 0.00000}
# [11/28 08:43:19][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.72074, "dt_data": 0.00061, "dt_net": 0.72013, "epoch": "195/200", "eta": "0:03:39", "gpu_mem": "15.89G", "grad_norm": 2.00199, "iter": "50/59", "loss": 0.03194, "lr": 0.00016, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:43:25][INFO] logging.py:   99: json_stats: {"RAM": "8.70/62.13G", "_type": "train_epoch", "dt": 0.19588, "dt_data": 0.19588, "dt_net": 0.70358, "epoch": "195/200", "eta": "0:00:57", "gpu_mem": "15.89G", "grad_norm": 0.36315, "loss": 0.06529, "lr": 0.00016, "top1_err": 2.43644, "top5_err": 0.00000}
# [11/28 08:43:25][INFO] train_net.py:  693: Epoch 194 takes 43.02s. Epochs from 4 to 194 take 43.01s in average and 43.01s in median.
# [11/28 08:43:25][INFO] train_net.py:  699: For epoch 194, each iteraction takes 0.73s in average. From epoch 4 to 194, each iteraction takes 0.73s in average.
# [11/28 08:43:25][INFO] precise_bn.py:  129: Computing precise BN statistics for 58 BN layers ...
# [11/28 08:43:50][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70548, "dt_data": 0.00068, "dt_net": 0.70480, "epoch": "196/200", "eta": "0:03:21", "gpu_mem": "15.89G", "grad_norm": 0.63713, "iter": "10/59", "loss": 0.03336, "lr": 0.00014, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:43:57][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70556, "dt_data": 0.00059, "dt_net": 0.70497, "epoch": "196/200", "eta": "0:03:14", "gpu_mem": "15.89G", "grad_norm": 2.67448, "iter": "20/59", "loss": 0.04580, "lr": 0.00013, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:44:04][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70512, "dt_data": 0.00055, "dt_net": 0.70457, "epoch": "196/200", "eta": "0:03:06", "gpu_mem": "15.89G", "grad_norm": 2.11599, "iter": "30/59", "loss": 0.07117, "lr": 0.00013, "top1_err": 3.12500, "top5_err": 0.00000}
# [11/28 08:44:11][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70690, "dt_data": 0.00064, "dt_net": 0.70626, "epoch": "196/200", "eta": "0:03:00", "gpu_mem": "15.89G", "grad_norm": 1.78771, "iter": "40/59", "loss": 0.10033, "lr": 0.00012, "top1_err": 3.12500, "top5_err": 0.00000}
# [11/28 08:44:18][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70625, "dt_data": 0.00054, "dt_net": 0.70571, "epoch": "196/200", "eta": "0:02:53", "gpu_mem": "15.89G", "grad_norm": 2.65770, "iter": "50/59", "loss": 0.09080, "lr": 0.00011, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:44:25][INFO] logging.py:   99: json_stats: {"RAM": "8.69/62.13G", "_type": "train_epoch", "dt": 0.19889, "dt_data": 0.19889, "dt_net": 0.70566, "epoch": "196/200", "eta": "0:00:46", "gpu_mem": "15.89G", "grad_norm": 0.31066, "loss": 0.10538, "lr": 0.00010, "top1_err": 2.96610, "top5_err": 0.00000}
# [11/28 08:44:25][INFO] train_net.py:  693: Epoch 195 takes 43.01s. Epochs from 4 to 195 take 43.01s in average and 43.01s in median.
# [11/28 08:44:25][INFO] train_net.py:  699: For epoch 195, each iteraction takes 0.73s in average. From epoch 4 to 195, each iteraction takes 0.73s in average.
# [11/28 08:44:25][INFO] precise_bn.py:  129: Computing precise BN statistics for 58 BN layers ...
# [11/28 08:44:49][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70482, "dt_data": 0.00052, "dt_net": 0.70431, "epoch": "197/200", "eta": "0:02:39", "gpu_mem": "15.89G", "grad_norm": 0.97634, "iter": "10/59", "loss": 0.02782, "lr": 0.00009, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:44:56][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.71461, "dt_data": 0.00048, "dt_net": 0.71413, "epoch": "197/200", "eta": "0:02:34", "gpu_mem": "15.89G", "grad_norm": 8.42613, "iter": "20/59", "loss": 0.03738, "lr": 0.00008, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:45:03][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70467, "dt_data": 0.00052, "dt_net": 0.70415, "epoch": "197/200", "eta": "0:02:25", "gpu_mem": "15.89G", "grad_norm": 3.61982, "iter": "30/59", "loss": 0.05441, "lr": 0.00008, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:45:10][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70574, "dt_data": 0.00057, "dt_net": 0.70517, "epoch": "197/200", "eta": "0:02:18", "gpu_mem": "15.89G", "grad_norm": 2.40329, "iter": "40/59", "loss": 0.06250, "lr": 0.00007, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:45:17][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70408, "dt_data": 0.00059, "dt_net": 0.70349, "epoch": "197/200", "eta": "0:02:10", "gpu_mem": "15.89G", "grad_norm": 2.39827, "iter": "50/59", "loss": 0.04395, "lr": 0.00006, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:45:24][INFO] logging.py:   99: json_stats: {"RAM": "8.70/62.13G", "_type": "train_epoch", "dt": 0.19992, "dt_data": 0.19992, "dt_net": 0.70479, "epoch": "197/200", "eta": "0:00:35", "gpu_mem": "15.89G", "grad_norm": 4.17219, "loss": 0.08542, "lr": 0.00006, "top1_err": 2.96610, "top5_err": 0.00000}
# [11/28 08:45:24][INFO] train_net.py:  693: Epoch 196 takes 43.22s. Epochs from 4 to 196 take 43.02s in average and 43.01s in median.
# [11/28 08:45:24][INFO] train_net.py:  699: For epoch 196, each iteraction takes 0.73s in average. From epoch 4 to 196, each iteraction takes 0.73s in average.
# [11/28 08:45:24][INFO] precise_bn.py:  129: Computing precise BN statistics for 58 BN layers ...
# [11/28 08:45:49][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70585, "dt_data": 0.00053, "dt_net": 0.70532, "epoch": "198/200", "eta": "0:01:57", "gpu_mem": "15.89G", "grad_norm": 5.26783, "iter": "10/59", "loss": 0.04419, "lr": 0.00005, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:45:56][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70482, "dt_data": 0.00061, "dt_net": 0.70421, "epoch": "198/200", "eta": "0:01:50", "gpu_mem": "15.89G", "grad_norm": 0.67531, "iter": "20/59", "loss": 0.03387, "lr": 0.00004, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:46:03][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70607, "dt_data": 0.00055, "dt_net": 0.70552, "epoch": "198/200", "eta": "0:01:43", "gpu_mem": "15.89G", "grad_norm": 1.16049, "iter": "30/59", "loss": 0.02652, "lr": 0.00004, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:46:10][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70402, "dt_data": 0.00048, "dt_net": 0.70354, "epoch": "198/200", "eta": "0:01:36", "gpu_mem": "15.89G", "grad_norm": 0.55540, "iter": "40/59", "loss": 0.04715, "lr": 0.00003, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:46:17][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70621, "dt_data": 0.00056, "dt_net": 0.70565, "epoch": "198/200", "eta": "0:01:29", "gpu_mem": "15.89G", "grad_norm": 1.19015, "iter": "50/59", "loss": 0.05361, "lr": 0.00003, "top1_err": 3.12500, "top5_err": 0.00000}
# [11/28 08:46:23][INFO] logging.py:   99: json_stats: {"RAM": "8.71/62.13G", "_type": "train_epoch", "dt": 0.18913, "dt_data": 0.18913, "dt_net": 0.70487, "epoch": "198/200", "eta": "0:00:22", "gpu_mem": "15.89G", "grad_norm": 0.49221, "loss": 0.07481, "lr": 0.00003, "top1_err": 2.22458, "top5_err": 0.00000}
# [11/28 08:46:23][INFO] train_net.py:  693: Epoch 197 takes 43.01s. Epochs from 4 to 197 take 43.02s in average and 43.01s in median.
# [11/28 08:46:23][INFO] train_net.py:  699: For epoch 197, each iteraction takes 0.73s in average. From epoch 4 to 197, each iteraction takes 0.73s in average.
# [11/28 08:46:23][INFO] precise_bn.py:  129: Computing precise BN statistics for 58 BN layers ...
# [11/28 08:46:48][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70566, "dt_data": 0.00065, "dt_net": 0.70502, "epoch": "199/200", "eta": "0:01:16", "gpu_mem": "15.89G", "grad_norm": 3.11234, "iter": "10/59", "loss": 0.11454, "lr": 0.00002, "top1_err": 6.25000, "top5_err": 0.00000}
# [11/28 08:46:55][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70530, "dt_data": 0.00050, "dt_net": 0.70480, "epoch": "199/200", "eta": "0:01:09", "gpu_mem": "15.89G", "grad_norm": 1.88228, "iter": "20/59", "loss": 0.04827, "lr": 0.00002, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:47:02][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70348, "dt_data": 0.00073, "dt_net": 0.70275, "epoch": "199/200", "eta": "0:01:01", "gpu_mem": "15.89G", "grad_norm": 2.35638, "iter": "30/59", "loss": 0.08192, "lr": 0.00001, "top1_err": 6.25000, "top5_err": 0.00000}
# [11/28 08:47:09][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70476, "dt_data": 0.00051, "dt_net": 0.70426, "epoch": "199/200", "eta": "0:00:54", "gpu_mem": "15.89G", "grad_norm": 4.70222, "iter": "40/59", "loss": 0.03220, "lr": 0.00001, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:47:16][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70573, "dt_data": 0.00092, "dt_net": 0.70482, "epoch": "199/200", "eta": "0:00:47", "gpu_mem": "15.89G", "grad_norm": 3.11736, "iter": "50/59", "loss": 0.01669, "lr": 0.00001, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:47:23][INFO] logging.py:   99: json_stats: {"RAM": "8.71/62.13G", "_type": "train_epoch", "dt": 0.19292, "dt_data": 0.19292, "dt_net": 0.70476, "epoch": "199/200", "eta": "0:00:11", "gpu_mem": "15.89G", "grad_norm": 0.17161, "loss": 0.07066, "lr": 0.00001, "top1_err": 2.64831, "top5_err": 0.00000}
# [11/28 08:47:23][INFO] train_net.py:  693: Epoch 198 takes 43.02s. Epochs from 4 to 198 take 43.02s in average and 43.01s in median.
# [11/28 08:47:23][INFO] train_net.py:  699: For epoch 198, each iteraction takes 0.73s in average. From epoch 4 to 198, each iteraction takes 0.73s in average.
# [11/28 08:47:23][INFO] precise_bn.py:  129: Computing precise BN statistics for 58 BN layers ...
# [11/28 08:47:47][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70580, "dt_data": 0.00080, "dt_net": 0.70500, "epoch": "200/200", "eta": "0:00:34", "gpu_mem": "15.89G", "grad_norm": 1.83548, "iter": "10/59", "loss": 0.02260, "lr": 0.00000, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:47:54][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.71509, "dt_data": 0.00067, "dt_net": 0.71441, "epoch": "200/200", "eta": "0:00:27", "gpu_mem": "15.89G", "grad_norm": 0.79372, "iter": "20/59", "loss": 0.03405, "lr": 0.00000, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:48:01][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70605, "dt_data": 0.00067, "dt_net": 0.70537, "epoch": "200/200", "eta": "0:00:20", "gpu_mem": "15.89G", "grad_norm": 6.76104, "iter": "30/59", "loss": 0.04041, "lr": 0.00000, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:48:08][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70943, "dt_data": 0.00062, "dt_net": 0.70881, "epoch": "200/200", "eta": "0:00:13", "gpu_mem": "15.89G", "grad_norm": 0.33396, "iter": "40/59", "loss": 0.01735, "lr": 0.00000, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:48:15][INFO] logging.py:   99: json_stats: {"_type": "train_iter_", "dt": 0.70458, "dt_data": 0.00064, "dt_net": 0.70394, "epoch": "200/200", "eta": "0:00:06", "gpu_mem": "15.89G", "grad_norm": 4.68674, "iter": "50/59", "loss": 0.06513, "lr": 0.00000, "top1_err": 0.00000, "top5_err": 0.00000}
# [11/28 08:48:22][INFO] logging.py:   99: json_stats: {"RAM": "8.70/62.13G", "_type": "train_epoch", "dt": 0.18983, "dt_data": 0.18983, "dt_net": 0.70262, "epoch": "200/200", "eta": "0:00:00", "gpu_mem": "15.89G", "grad_norm": 0.27916, "loss": 0.07654, "lr": 0.00000, "top1_err": 2.22458, "top5_err": 0.00000}
# [11/28 08:48:22][INFO] train_net.py:  693: Epoch 199 takes 43.00s. Epochs from 4 to 199 take 43.01s in average and 43.01s in median.
# [11/28 08:48:22][INFO] train_net.py:  699: For epoch 199, each iteraction takes 0.73s in average. From epoch 4 to 199, each iteraction takes 0.73s in average.
# [11/28 08:48:22][INFO] precise_bn.py:  129: Computing precise BN statistics for 58 BN layers ...
# [11/28 08:48:41][INFO] logging.py:   99: json_stats: {"_type": "val_iter", "epoch": "200/200", "eta": "0:00:02", "gpu_mem": "15.89G", "iter": "10/19", "time_diff": 0.23152, "top1_err": 93.75000, "top5_err": 43.75000}
# [11/28 08:48:43][INFO] logging.py:   99: json_stats: {"RAM": "8.72/62.13G", "_type": "val_epoch", "epoch": "200/200", "gpu_mem": "15.89G", "min_top1_err": 93.72937, "min_top5_err": 37.62376, "time_diff": 0.11586, "top1_err": 95.70957, "top5_err": 39.93399}
# [11/28 08:48:43][INFO] train_net.py:  776: training done: _p39.01_f64.18 _t0.72_m15.89 _a6.27 Top5 Acc: 62.38 MEM: 15.89 f: 64.1751

# %% [markdown]
# **Testing**

# %%
# !python tools/run_net.py --cfg configs/MyData/SLOW_NLN_8x8_R50-Test.yaml
# Out:
# /opt/conda/lib/python3.7/site-packages/torchvision/transforms/_functional_video.py:7: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   "The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. "
# /opt/conda/lib/python3.7/site-packages/torchvision/transforms/_transforms_video.py:23: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   "The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. "
# config files: ['configs/MyData/SLOW_NLN_8x8_R50-Test.yaml']
# [11/28 09:04:04][INFO] test_net.py:  190: Test with config:
# [11/28 09:04:04][INFO] test_net.py:  191: AUG:
#   AA_TYPE: rand-m9-mstd0.5-inc1
#   COLOR_JITTER: 0.4
#   ENABLE: False
#   GEN_MASK_LOADER: False
#   INTERPOLATION: bicubic
#   MASK_FRAMES: False
#   MASK_RATIO: 0.0
#   MASK_TUBE: False
#   MASK_WINDOW_SIZE: [8, 7, 7]
#   MAX_MASK_PATCHES_PER_BLOCK: None
#   NUM_SAMPLE: 1
#   RE_COUNT: 1
#   RE_MODE: pixel
#   RE_PROB: 0.25
#   RE_SPLIT: False
# AVA:
#   ANNOTATION_DIR: /mnt/vol/gfsai-flash3-east/ai-group/users/haoqifan/ava/frame_list/
#   BGR: False
#   DETECTION_SCORE_THRESH: 0.9
#   EXCLUSION_FILE: ava_val_excluded_timestamps_v2.2.csv
#   FRAME_DIR: /mnt/fair-flash3-east/ava_trainval_frames.img/
#   FRAME_LIST_DIR: /mnt/vol/gfsai-flash3-east/ai-group/users/haoqifan/ava/frame_list/
#   FULL_TEST_ON_VAL: False
#   GROUNDTRUTH_FILE: ava_val_v2.2.csv
#   IMG_PROC_BACKEND: cv2
#   LABEL_MAP_FILE: ava_action_list_v2.2_for_activitynet_2019.pbtxt
#   TEST_FORCE_FLIP: False
#   TEST_LISTS: ['val.csv']
#   TEST_PREDICT_BOX_LISTS: ['ava_val_predicted_boxes.csv']
#   TRAIN_GT_BOX_LISTS: ['ava_train_v2.2.csv']
#   TRAIN_LISTS: ['train.csv']
#   TRAIN_PCA_JITTER_ONLY: True
#   TRAIN_PREDICT_BOX_LISTS: []
#   TRAIN_USE_COLOR_AUGMENTATION: False
# BENCHMARK:
#   LOG_PERIOD: 100
#   NUM_EPOCHS: 5
#   SHUFFLE: True
# BN:
#   GLOBAL_SYNC: False
#   NORM_TYPE: batchnorm
#   NUM_BATCHES_PRECISE: 200
#   NUM_SPLITS: 1
#   NUM_SYNC_DEVICES: 1
#   USE_PRECISE_STATS: True
#   WEIGHT_DECAY: 0.0
# CONTRASTIVE:
#   BN_MLP: False
#   BN_SYNC_MLP: False
#   DELTA_CLIPS_MAX: inf
#   DELTA_CLIPS_MIN: -inf
#   DIM: 128
#   INTERP_MEMORY: False
#   KNN_ON: True
#   LENGTH: 239975
#   LOCAL_SHUFFLE_BN: True
#   MEM_TYPE: 1d
#   MLP_DIM: 2048
#   MOCO_MULTI_VIEW_QUEUE: False
#   MOMENTUM: 0.5
#   MOMENTUM_ANNEALING: False
#   NUM_CLASSES_DOWNSTREAM: 13
#   NUM_MLP_LAYERS: 1
#   PREDICTOR_DEPTHS: []
#   QUEUE_LEN: 65536
#   SEQUENTIAL: False
#   SIMCLR_DIST_ON: True
#   SWAV_QEUE_LEN: 0
#   T: 0.07
#   TYPE: mem
# DATA:
#   COLOR_RND_GRAYSCALE: 0.0
#   DECODING_BACKEND: pyav
#   DECODING_SHORT_SIZE: 256
#   DUMMY_LOAD: False
#   ENSEMBLE_METHOD: sum
#   IN22K_TRAINVAL: False
#   IN22k_VAL_IN1K:
#   INPUT_CHANNEL_NUM: [3]
#   INV_UNIFORM_SAMPLE: False
#   IN_VAL_CROP_RATIO: 0.875
#   LOADER_CHUNK_OVERALL_SIZE: 0
#   LOADER_CHUNK_SIZE: 0
#   MEAN: [0.45, 0.45, 0.45]
#   MULTI_LABEL: False
#   NUM_FRAMES: 8
#   PATH_LABEL_SEPARATOR:
#   PATH_PREFIX:
#   PATH_TO_DATA_DIR: /workspace/slowfast/data/MyData
#   PATH_TO_PRELOAD_IMDB:
#   RANDOM_FLIP: True
#   REVERSE_INPUT_CHANNEL: False
#   SAMPLING_RATE: 8
#   SKIP_ROWS: 0
#   SSL_BLUR_SIGMA_MAX: [0.0, 2.0]
#   SSL_BLUR_SIGMA_MIN: [0.0, 0.1]
#   SSL_COLOR_BRI_CON_SAT: [0.4, 0.4, 0.4]
#   SSL_COLOR_HUE: 0.1
#   SSL_COLOR_JITTER: False
#   SSL_MOCOV2_AUG: False
#   STD: [0.225, 0.225, 0.225]
#   TARGET_FPS: 30
#   TEST_CROP_SIZE: 256
#   TIME_DIFF_PROB: 0.0
#   TRAIN_CROP_NUM_SPATIAL: 1
#   TRAIN_CROP_NUM_TEMPORAL: 1
#   TRAIN_CROP_SIZE: 224
#   TRAIN_JITTER_ASPECT_RELATIVE: []
#   TRAIN_JITTER_FPS: 0.0
#   TRAIN_JITTER_MOTION_SHIFT: False
#   TRAIN_JITTER_SCALES: [256, 320]
#   TRAIN_JITTER_SCALES_RELATIVE: []
#   TRAIN_PCA_EIGVAL: [0.225, 0.224, 0.229]
#   TRAIN_PCA_EIGVEC: [[-0.5675, 0.7192, 0.4009], [-0.5808, -0.0045, -0.814], [-0.5836, -0.6948, 0.4203]]
#   USE_OFFSET_SAMPLING: False
# DATA_LOADER:
#   ENABLE_MULTI_THREAD_DECODE: False
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# DEMO:
#   BUFFER_SIZE: 0
#   CLIP_VIS_SIZE: 10
#   COMMON_CLASS_NAMES: ['watch (a person)', 'talk to (e.g., self, a person, a group)', 'listen to (a person)', 'touch (an object)', 'carry/hold (an object)', 'walk', 'sit', 'lie/sleep', 'bend/bow (at the waist)']
#   COMMON_CLASS_THRES: 0.25
#   DETECTRON2_CFG: COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml
#   DETECTRON2_THRESH: 0.9
#   DETECTRON2_WEIGHTS: detectron2://COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl
#   DISPLAY_HEIGHT: 0
#   DISPLAY_WIDTH: 0
#   ENABLE: False
#   FPS: 30
#   GT_BOXES:
#   INPUT_FORMAT: BGR
#   INPUT_VIDEO: /workspace/slowfast/data/MyData/Abuse/Abuse001_x264.mp4
#   LABEL_FILE_PATH: /workspace/slowfast/data/MyData/classids.json
#   NUM_CLIPS_SKIP: 0
#   NUM_VIS_INSTANCES: 2
#   OUTPUT_FILE: /workspace/slowfast/data/MyData/output.mp4
#   OUTPUT_FPS: -1
#   PREDS_BOXES:
#   SLOWMO: 1
#   STARTING_SECOND: 900
#   THREAD_ENABLE: False
#   UNCOMMON_CLASS_THRES: 0.3
#   VIS_MODE: thres
#   WEBCAM: -1
# DETECTION:
#   ALIGNED: True
#   ENABLE: False
#   ROI_XFORM_RESOLUTION: 7
#   SPATIAL_SCALE_FACTOR: 16
# DIST_BACKEND: nccl
# LOG_MODEL_INFO: True
# LOG_PERIOD: 10
# MASK:
#   DECODER_DEPTH: 0
#   DECODER_EMBED_DIM: 512
#   DECODER_SEP_POS_EMBED: False
#   DEC_KV_KERNEL: []
#   DEC_KV_STRIDE: []
#   ENABLE: False
#   HEAD_TYPE: separate
#   MAE_ON: False
#   MAE_RND_MASK: False
#   NORM_PRED_PIXEL: True
#   PER_FRAME_MASKING: False
#   PRED_HOG: False
#   PRETRAIN_DEPTH: [15]
#   SCALE_INIT_BY_DEPTH: False
#   TIME_STRIDE_LOSS: True
# MIXUP:
#   ALPHA: 0.8
#   CUTMIX_ALPHA: 1.0
#   ENABLE: False
#   LABEL_SMOOTH_VALUE: 0.1
#   PROB: 1.0
#   SWITCH_PROB: 0.5
# MODEL:
#   ACT_CHECKPOINT: False
#   ARCH: slow
#   DETACH_FINAL_FC: False
#   DROPCONNECT_RATE: 0.0
#   DROPOUT_RATE: 0.5
#   FC_INIT_STD: 0.01
#   FP16_ALLREDUCE: False
#   FROZEN_BN: False
#   HEAD_ACT: softmax
#   LOSS_FUNC: cross_entropy
#   MODEL_NAME: ResNet
#   MULTI_PATHWAY_ARCH: ['slowfast']
#   NUM_CLASSES: 7
#   SINGLE_PATHWAY_ARCH: ['2d', 'c2d', 'i3d', 'slow', 'x3d', 'mvit', 'maskmvit']
# MULTIGRID:
#   BN_BASE_SIZE: 8
#   DEFAULT_B: 0
#   DEFAULT_S: 0
#   DEFAULT_T: 0
#   EPOCH_FACTOR: 1.5
#   EVAL_FREQ: 3
#   LONG_CYCLE: False
#   LONG_CYCLE_FACTORS: [(0.25, 0.7071067811865476), (0.5, 0.7071067811865476), (0.5, 1), (1, 1)]
#   LONG_CYCLE_SAMPLING_RATE: 0
#   SHORT_CYCLE: False
#   SHORT_CYCLE_FACTORS: [0.5, 0.7071067811865476]
# MVIT:
#   CLS_EMBED_ON: True
#   DEPTH: 16
#   DIM_MUL: []
#   DIM_MUL_IN_ATT: False
#   DROPOUT_RATE: 0.0
#   DROPPATH_RATE: 0.1
#   EMBED_DIM: 96
#   HEAD_INIT_SCALE: 1.0
#   HEAD_MUL: []
#   LAYER_SCALE_INIT_VALUE: 0.0
#   MLP_RATIO: 4.0
#   MODE: conv
#   NORM: layernorm
#   NORM_STEM: False
#   NUM_HEADS: 1
#   PATCH_2D: False
#   PATCH_KERNEL: [3, 7, 7]
#   PATCH_PADDING: [2, 4, 4]
#   PATCH_STRIDE: [2, 4, 4]
#   POOL_FIRST: False
#   POOL_KVQ_KERNEL: None
#   POOL_KV_STRIDE: []
#   POOL_KV_STRIDE_ADAPTIVE: None
#   POOL_Q_STRIDE: []
#   QKV_BIAS: True
#   REL_POS_SPATIAL: False
#   REL_POS_TEMPORAL: False
#   REL_POS_ZERO_INIT: False
#   RESIDUAL_POOLING: False
#   REV:
#     BUFFER_LAYERS: []
#     ENABLE: False
#     PRE_Q_FUSION: avg
#     RESPATH_FUSE: concat
#     RES_PATH: conv
#   SEPARATE_QKV: False
#   SEP_POS_EMBED: False
#   USE_ABS_POS: True
#   USE_FIXED_SINCOS_POS: False
#   USE_MEAN_POOLING: False
#   ZERO_DECAY_POS_CLS: True
# NONLOCAL:
#   GROUP: [[1], [1], [1], [1]]
#   INSTANTIATION: dot_product
#   LOCATION: [[[]], [[1, 3]], [[1, 3, 5]], [[]]]
#   POOL: [[[1, 2, 2], [1, 2, 2]], [[1, 2, 2], [1, 2, 2]], [[1, 2, 2], [1, 2, 2]], [[1, 2, 2], [1, 2, 2]]]
# NUM_GPUS: 1
# NUM_SHARDS: 1
# OUTPUT_DIR: .
# RESNET:
#   DEPTH: 50
#   INPLACE_RELU: True
#   NUM_BLOCK_TEMP_KERNEL: [[3], [4], [6], [3]]
#   NUM_GROUPS: 1
#   SPATIAL_DILATIONS: [[1], [1], [1], [1]]
#   SPATIAL_STRIDES: [[1], [2], [2], [2]]
#   STRIDE_1X1: False
#   TRANS_FUNC: bottleneck_transform
#   WIDTH_PER_GROUP: 64
#   ZERO_INIT_FINAL_BN: True
#   ZERO_INIT_FINAL_CONV: False
# RNG_SEED: 0
# SHARD_ID: 0
# SLOWFAST:
#   ALPHA: 8
#   BETA_INV: 8
#   FUSION_CONV_CHANNEL_RATIO: 2
#   FUSION_KERNEL_SZ: 5
# SOLVER:
#   BASE_LR: 0.1
#   BASE_LR_SCALE_NUM_SHARDS: False
#   BETAS: (0.9, 0.999)
#   CLIP_GRAD_L2NORM: None
#   CLIP_GRAD_VAL: None
#   COSINE_AFTER_WARMUP: False
#   COSINE_END_LR: 0.0
#   DAMPENING: 0.0
#   GAMMA: 0.1
#   LARS_ON: False
#   LAYER_DECAY: 1.0
#   LRS: []
#   LR_POLICY: cosine
#   MAX_EPOCH: 200
#   MOMENTUM: 0.9
#   NESTEROV: True
#   OPTIMIZING_METHOD: sgd
#   STEPS: []
#   STEP_SIZE: 1
#   WARMUP_EPOCHS: 34.0
#   WARMUP_FACTOR: 0.1
#   WARMUP_START_LR: 0.01
#   WEIGHT_DECAY: 0.0001
#   ZERO_WD_1D_PARAM: False
# TASK:
# TENSORBOARD:
#   CATEGORIES_PATH:
#   CLASS_NAMES_PATH: /workspace/slowfast/data/MyData/classids.json
#   CONFUSION_MATRIX:
#     ENABLE: True
#     FIGSIZE: [8, 8]
#     SUBSET_PATH:
#   ENABLE: True
#   HISTOGRAM:
#     ENABLE: False
#     FIGSIZE: [8, 8]
#     SUBSET_PATH:
#     TOPK: 10
#   LOG_DIR:
#   MODEL_VIS:
#     ACTIVATIONS: False
#     COLORMAP: Pastel2
#     ENABLE: False
#     GRAD_CAM:
#       COLORMAP: viridis
#       ENABLE: True
#       LAYER_LIST: []
#       USE_TRUE_LABEL: False
#     INPUT_VIDEO: False
#     LAYER_LIST: []
#     MODEL_WEIGHTS: False
#     TOPK_PREDS: 1
#   PREDICTIONS_PATH:
#   WRONG_PRED_VIS:
#     ENABLE: False
#     SUBSET_PATH:
#     TAG: Incorrectly classified videos.
# TEST:
#   BATCH_SIZE: 16
#   CHECKPOINT_FILE_PATH: /workspace/slowfast/submit_checkpoint/checkpoint_epoch_00200.pyth
#   CHECKPOINT_TYPE: pytorch
#   DATASET: mydata
#   ENABLE: True
#   NUM_ENSEMBLE_VIEWS: 10
#   NUM_SPATIAL_CROPS: 3
#   NUM_TEMPORAL_CLIPS: [10]
#   SAVE_RESULTS_PATH: output1.pkl
# TRAIN:
#   AUTO_RESUME: True
#   BATCH_SIZE: 16
#   CHECKPOINT_CLEAR_NAME_PATTERN: ()
#   CHECKPOINT_EPOCH_RESET: False
#   CHECKPOINT_FILE_PATH:
#   CHECKPOINT_INFLATE: False
#   CHECKPOINT_IN_INIT: False
#   CHECKPOINT_PERIOD: 1
#   CHECKPOINT_TYPE: pytorch
#   DATASET: mydata
#   ENABLE: False
#   EVAL_PERIOD: 10
#   KILL_LOSS_EXPLOSION_FACTOR: 0.0
#   MIXED_PRECISION: False
# VIS_MASK:
#   ENABLE: False
# X3D:
#   BN_LIN5: False
#   BOTTLENECK_FACTOR: 1.0
#   CHANNELWISE_3x3x3: True
#   DEPTH_FACTOR: 1.0
#   DIM_C1: 12
#   DIM_C5: 2048
#   SCALE_RES2: False
#   WIDTH_FACTOR: 1.0
# [11/28 09:04:06][INFO] misc.py:  185: Model:
# ResNet(
#   (s1): VideoModelStem(
#     (pathway0_stem): ResNetBasicStem(
#       (conv): Conv3d(3, 64, kernel_size=(1, 7, 7), stride=(1, 2, 2), padding=(0, 3, 3), bias=False)
#       (bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (pool_layer): MaxPool3d(kernel_size=[1, 3, 3], stride=[1, 2, 2], padding=[0, 1, 1], dilation=1, ceil_mode=False)
#     )
#   )
#   (s2): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (branch1_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (pathway0_pool): MaxPool3d(kernel_size=[1, 1, 1], stride=[1, 1, 1], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#   (s3): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal1): Nonlocal(
#       (conv_theta): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res3): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal3): Nonlocal(
#       (conv_theta): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#   )
#   (s4): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal1): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res3): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal3): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res4): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res5): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal5): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#   )
#   (s5): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (head): ResNetBasicHead(
#     (predictors): ModuleList()
#     (pathway0_avgpool): AvgPool3d(kernel_size=[8, 7, 7], stride=1, padding=0)
#     (dropout): Dropout(p=0.5, inplace=False)
#     (projection): Linear(in_features=2048, out_features=7, bias=True)
#     (act): Softmax(dim=4)
#   )
# )
# [11/28 09:04:06][INFO] misc.py:  187: Params: 39,007,303
# [11/28 09:04:06][INFO] misc.py:  188: Mem: 0.14655351638793945 MB
# [11/28 09:04:07][WARNING] jit_analysis.py:  500: Unsupported operator aten::max_pool3d encountered 7 time(s)
# [11/28 09:04:07][WARNING] jit_analysis.py:  500: Unsupported operator aten::add encountered 21 time(s)
# [11/28 09:04:07][WARNING] jit_analysis.py:  500: Unsupported operator aten::div encountered 5 time(s)
# [11/28 09:04:07][WARNING] jit_analysis.py:  500: Unsupported operator aten::avg_pool3d encountered 1 time(s)
# [11/28 09:04:07][WARNING] jit_analysis.py:  500: Unsupported operator aten::softmax encountered 1 time(s)
# [11/28 09:04:07][WARNING] jit_analysis.py:  500: Unsupported operator aten::mean encountered 1 time(s)
# [11/28 09:04:07][INFO] misc.py:  190: Flops: 88.602107904 G
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::batch_norm encountered 58 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::max_pool3d encountered 7 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::add encountered 21 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::div encountered 5 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::avg_pool3d encountered 1 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::softmax encountered 1 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::mean encountered 1 time(s)
# [11/28 09:04:08][INFO] misc.py:  193: Activations: 185.86012399999998 M
# [11/28 09:04:08][INFO] misc.py:  196: nvidia-smi
# Mon Nov 28 09:04:08 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.141.03   Driver Version: 470.141.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A10G         Off  | 00000000:00:1E.0 Off |                    0 |
# |  0%   19C    P0    61W / 300W |   3027MiB / 22731MiB |     10%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# [11/28 09:04:08][INFO] misc.py:  185: Model:
# ResNet(
#   (s1): VideoModelStem(
#     (pathway0_stem): ResNetBasicStem(
#       (conv): Conv3d(3, 64, kernel_size=(1, 7, 7), stride=(1, 2, 2), padding=(0, 3, 3), bias=False)
#       (bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (pool_layer): MaxPool3d(kernel_size=[1, 3, 3], stride=[1, 2, 2], padding=[0, 1, 1], dilation=1, ceil_mode=False)
#     )
#   )
#   (s2): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (branch1_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (pathway0_pool): MaxPool3d(kernel_size=[1, 1, 1], stride=[1, 1, 1], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#   (s3): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal1): Nonlocal(
#       (conv_theta): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res3): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal3): Nonlocal(
#       (conv_theta): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#   )
#   (s4): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal1): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res3): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal3): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res4): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res5): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal5): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#   )
#   (s5): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (head): ResNetBasicHead(
#     (predictors): ModuleList()
#     (pathway0_avgpool): AvgPool3d(kernel_size=[8, 7, 7], stride=1, padding=0)
#     (dropout): Dropout(p=0.5, inplace=False)
#     (projection): Linear(in_features=2048, out_features=7, bias=True)
#     (act): Softmax(dim=4)
#   )
# )
# [11/28 09:04:08][INFO] misc.py:  187: Params: 39,007,303
# [11/28 09:04:08][INFO] misc.py:  188: Mem: 1.5985279083251953 MB
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::max_pool3d encountered 7 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::add encountered 21 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::div encountered 5 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::avg_pool3d encountered 1 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::softmax encountered 1 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::mean encountered 1 time(s)
# [11/28 09:04:08][INFO] misc.py:  190: Flops: 88.602107904 G
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::batch_norm encountered 58 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::max_pool3d encountered 7 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::add encountered 21 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::div encountered 5 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::avg_pool3d encountered 1 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::softmax encountered 1 time(s)
# [11/28 09:04:08][WARNING] jit_analysis.py:  500: Unsupported operator aten::mean encountered 1 time(s)
# [11/28 09:04:08][INFO] misc.py:  193: Activations: 185.86012399999998 M
# ...
# [11/28 09:06:27][INFO] logging.py:   99: json_stats: {"cur_iter": "456", "eta": "0:00:34", "split": "test_iter", "time_diff": 0.30269}
# [11/28 09:06:28][INFO] logging.py:   99: json_stats: {"cur_iter": "457", "eta": "0:00:33", "split": "test_iter", "time_diff": 0.29470}
# [11/28 09:06:28][INFO] logging.py:   99: json_stats: {"cur_iter": "458", "eta": "0:00:32", "split": "test_iter", "time_diff": 0.29255}
# [11/28 09:06:28][INFO] logging.py:   99: json_stats: {"cur_iter": "459", "eta": "0:00:32", "split": "test_iter", "time_diff": 0.29085}
# [11/28 09:06:29][INFO] logging.py:   99: json_stats: {"cur_iter": "460", "eta": "0:00:32", "split": "test_iter", "time_diff": 0.29897}
# [11/28 09:06:29][INFO] logging.py:   99: json_stats: {"cur_iter": "461", "eta": "0:00:32", "split": "test_iter", "time_diff": 0.29988}
# [11/28 09:06:29][INFO] logging.py:   99: json_stats: {"cur_iter": "462", "eta": "0:00:31", "split": "test_iter", "time_diff": 0.29600}
# [11/28 09:06:30][INFO] logging.py:   99: json_stats: {"cur_iter": "463", "eta": "0:00:32", "split": "test_iter", "time_diff": 0.30246}
# [11/28 09:06:30][INFO] logging.py:   99: json_stats: {"cur_iter": "464", "eta": "0:00:30", "split": "test_iter", "time_diff": 0.29163}
# [11/28 09:06:30][INFO] logging.py:   99: json_stats: {"cur_iter": "465", "eta": "0:00:31", "split": "test_iter", "time_diff": 0.30366}
# [11/28 09:06:30][INFO] logging.py:   99: json_stats: {"cur_iter": "466", "eta": "0:00:30", "split": "test_iter", "time_diff": 0.29317}
# [11/28 09:06:31][INFO] logging.py:   99: json_stats: {"cur_iter": "467", "eta": "0:00:31", "split": "test_iter", "time_diff": 0.30102}
# [11/28 09:06:31][INFO] logging.py:   99: json_stats: {"cur_iter": "468", "eta": "0:00:30", "split": "test_iter", "time_diff": 0.29994}
# [11/28 09:06:31][INFO] logging.py:   99: json_stats: {"cur_iter": "469", "eta": "0:00:30", "split": "test_iter", "time_diff": 0.30177}
# [11/28 09:06:32][INFO] logging.py:   99: json_stats: {"cur_iter": "470", "eta": "0:00:29", "split": "test_iter", "time_diff": 0.29680}
# [11/28 09:06:32][INFO] logging.py:   99: json_stats: {"cur_iter": "471", "eta": "0:00:29", "split": "test_iter", "time_diff": 0.30048}
# [11/28 09:06:32][INFO] logging.py:   99: json_stats: {"cur_iter": "472", "eta": "0:00:30", "split": "test_iter", "time_diff": 0.30658}
# [11/28 09:06:33][INFO] logging.py:   99: json_stats: {"cur_iter": "473", "eta": "0:00:29", "split": "test_iter", "time_diff": 0.30288}
# [11/28 09:06:33][INFO] logging.py:   99: json_stats: {"cur_iter": "474", "eta": "0:00:28", "split": "test_iter", "time_diff": 0.29532}
# [11/28 09:06:33][INFO] logging.py:   99: json_stats: {"cur_iter": "475", "eta": "0:00:28", "split": "test_iter", "time_diff": 0.29921}
# [11/28 09:06:33][INFO] logging.py:   99: json_stats: {"cur_iter": "476", "eta": "0:00:28", "split": "test_iter", "time_diff": 0.30098}
# [11/28 09:06:34][INFO] logging.py:   99: json_stats: {"cur_iter": "477", "eta": "0:00:27", "split": "test_iter", "time_diff": 0.30071}
# [11/28 09:06:34][INFO] logging.py:   99: json_stats: {"cur_iter": "478", "eta": "0:00:26", "split": "test_iter", "time_diff": 0.29261}
# [11/28 09:06:34][INFO] logging.py:   99: json_stats: {"cur_iter": "479", "eta": "0:00:27", "split": "test_iter", "time_diff": 0.30380}
# [11/28 09:06:35][INFO] logging.py:   99: json_stats: {"cur_iter": "480", "eta": "0:00:26", "split": "test_iter", "time_diff": 0.29491}
# [11/28 09:06:35][INFO] logging.py:   99: json_stats: {"cur_iter": "481", "eta": "0:00:26", "split": "test_iter", "time_diff": 0.29787}
# [11/28 09:06:35][INFO] logging.py:   99: json_stats: {"cur_iter": "482", "eta": "0:00:25", "split": "test_iter", "time_diff": 0.29287}
# [11/28 09:06:36][INFO] logging.py:   99: json_stats: {"cur_iter": "483", "eta": "0:00:26", "split": "test_iter", "time_diff": 0.29993}
# [11/28 09:06:36][INFO] logging.py:   99: json_stats: {"cur_iter": "484", "eta": "0:00:25", "split": "test_iter", "time_diff": 0.30074}
# [11/28 09:06:36][INFO] logging.py:   99: json_stats: {"cur_iter": "485", "eta": "0:00:25", "split": "test_iter", "time_diff": 0.29976}
# [11/28 09:06:36][INFO] logging.py:   99: json_stats: {"cur_iter": "486", "eta": "0:00:24", "split": "test_iter", "time_diff": 0.29740}
# [11/28 09:06:37][INFO] logging.py:   99: json_stats: {"cur_iter": "487", "eta": "0:00:25", "split": "test_iter", "time_diff": 0.30135}
# [11/28 09:06:37][INFO] logging.py:   99: json_stats: {"cur_iter": "488", "eta": "0:00:25", "split": "test_iter", "time_diff": 0.30569}
# [11/28 09:06:37][INFO] logging.py:   99: json_stats: {"cur_iter": "489", "eta": "0:00:24", "split": "test_iter", "time_diff": 0.29882}
# [11/28 09:06:38][INFO] logging.py:   99: json_stats: {"cur_iter": "490", "eta": "0:00:23", "split": "test_iter", "time_diff": 0.29517}
# [11/28 09:06:38][INFO] logging.py:   99: json_stats: {"cur_iter": "491", "eta": "0:00:23", "split": "test_iter", "time_diff": 0.29927}
# [11/28 09:06:38][INFO] logging.py:   99: json_stats: {"cur_iter": "492", "eta": "0:00:23", "split": "test_iter", "time_diff": 0.30674}
# [11/28 09:06:39][INFO] logging.py:   99: json_stats: {"cur_iter": "493", "eta": "0:00:23", "split": "test_iter", "time_diff": 0.30081}
# [11/28 09:06:39][INFO] logging.py:   99: json_stats: {"cur_iter": "494", "eta": "0:00:22", "split": "test_iter", "time_diff": 0.29372}
# [11/28 09:06:39][INFO] logging.py:   99: json_stats: {"cur_iter": "495", "eta": "0:00:22", "split": "test_iter", "time_diff": 0.29933}
# [11/28 09:06:39][INFO] logging.py:   99: json_stats: {"cur_iter": "496", "eta": "0:00:22", "split": "test_iter", "time_diff": 0.29732}
# [11/28 09:06:40][INFO] logging.py:   99: json_stats: {"cur_iter": "497", "eta": "0:00:22", "split": "test_iter", "time_diff": 0.30263}
# [11/28 09:06:40][INFO] logging.py:   99: json_stats: {"cur_iter": "498", "eta": "0:00:21", "split": "test_iter", "time_diff": 0.29343}
# [11/28 09:06:40][INFO] logging.py:   99: json_stats: {"cur_iter": "499", "eta": "0:00:21", "split": "test_iter", "time_diff": 0.29984}
# [11/28 09:06:41][INFO] logging.py:   99: json_stats: {"cur_iter": "500", "eta": "0:00:20", "split": "test_iter", "time_diff": 0.29972}
# [11/28 09:06:41][INFO] logging.py:   99: json_stats: {"cur_iter": "501", "eta": "0:00:20", "split": "test_iter", "time_diff": 0.30127}
# [11/28 09:06:41][INFO] logging.py:   99: json_stats: {"cur_iter": "502", "eta": "0:00:20", "split": "test_iter", "time_diff": 0.30314}
# [11/28 09:06:42][INFO] logging.py:   99: json_stats: {"cur_iter": "503", "eta": "0:00:19", "split": "test_iter", "time_diff": 0.29790}
# [11/28 09:06:42][INFO] logging.py:   99: json_stats: {"cur_iter": "504", "eta": "0:00:19", "split": "test_iter", "time_diff": 0.29118}
# [11/28 09:06:42][INFO] logging.py:   99: json_stats: {"cur_iter": "505", "eta": "0:00:19", "split": "test_iter", "time_diff": 0.30140}
# [11/28 09:06:42][INFO] logging.py:   99: json_stats: {"cur_iter": "506", "eta": "0:00:19", "split": "test_iter", "time_diff": 0.29883}
# [11/28 09:06:43][INFO] logging.py:   99: json_stats: {"cur_iter": "507", "eta": "0:00:18", "split": "test_iter", "time_diff": 0.30074}
# [11/28 09:06:43][INFO] logging.py:   99: json_stats: {"cur_iter": "508", "eta": "0:00:18", "split": "test_iter", "time_diff": 0.29178}
# [11/28 09:06:43][INFO] logging.py:   99: json_stats: {"cur_iter": "509", "eta": "0:00:18", "split": "test_iter", "time_diff": 0.30212}
# [11/28 09:06:44][INFO] logging.py:   99: json_stats: {"cur_iter": "510", "eta": "0:00:17", "split": "test_iter", "time_diff": 0.29302}
# [11/28 09:06:44][INFO] logging.py:   99: json_stats: {"cur_iter": "511", "eta": "0:00:17", "split": "test_iter", "time_diff": 0.30389}
# [11/28 09:06:44][INFO] logging.py:   99: json_stats: {"cur_iter": "512", "eta": "0:00:16", "split": "test_iter", "time_diff": 0.29243}
# [11/28 09:06:45][INFO] logging.py:   99: json_stats: {"cur_iter": "513", "eta": "0:00:17", "split": "test_iter", "time_diff": 0.30367}
# [11/28 09:06:45][INFO] logging.py:   99: json_stats: {"cur_iter": "514", "eta": "0:00:16", "split": "test_iter", "time_diff": 0.29330}
# [11/28 09:06:45][INFO] logging.py:   99: json_stats: {"cur_iter": "515", "eta": "0:00:16", "split": "test_iter", "time_diff": 0.29908}
# [11/28 09:06:45][INFO] logging.py:   99: json_stats: {"cur_iter": "516", "eta": "0:00:16", "split": "test_iter", "time_diff": 0.29722}
# [11/28 09:06:46][INFO] logging.py:   99: json_stats: {"cur_iter": "517", "eta": "0:00:15", "split": "test_iter", "time_diff": 0.29905}
# [11/28 09:06:46][INFO] logging.py:   99: json_stats: {"cur_iter": "518", "eta": "0:00:15", "split": "test_iter", "time_diff": 0.30135}
# [11/28 09:06:46][INFO] logging.py:   99: json_stats: {"cur_iter": "519", "eta": "0:00:15", "split": "test_iter", "time_diff": 0.30179}
# [11/28 09:06:47][INFO] logging.py:   99: json_stats: {"cur_iter": "520", "eta": "0:00:15", "split": "test_iter", "time_diff": 0.30382}
# [11/28 09:06:47][INFO] logging.py:   99: json_stats: {"cur_iter": "521", "eta": "0:00:14", "split": "test_iter", "time_diff": 0.29469}
# [11/28 09:06:47][INFO] logging.py:   99: json_stats: {"cur_iter": "522", "eta": "0:00:14", "split": "test_iter", "time_diff": 0.29330}
# [11/28 09:06:48][INFO] logging.py:   99: json_stats: {"cur_iter": "523", "eta": "0:00:14", "split": "test_iter", "time_diff": 0.30010}
# [11/28 09:06:48][INFO] logging.py:   99: json_stats: {"cur_iter": "524", "eta": "0:00:13", "split": "test_iter", "time_diff": 0.29139}
# [11/28 09:06:48][INFO] logging.py:   99: json_stats: {"cur_iter": "525", "eta": "0:00:13", "split": "test_iter", "time_diff": 0.29977}
# [11/28 09:06:48][INFO] logging.py:   99: json_stats: {"cur_iter": "526", "eta": "0:00:13", "split": "test_iter", "time_diff": 0.30636}
# [11/28 09:06:49][INFO] logging.py:   99: json_stats: {"cur_iter": "527", "eta": "0:00:12", "split": "test_iter", "time_diff": 0.30108}
# [11/28 09:06:49][INFO] logging.py:   99: json_stats: {"cur_iter": "528", "eta": "0:00:12", "split": "test_iter", "time_diff": 0.29720}
# [11/28 09:06:49][INFO] logging.py:   99: json_stats: {"cur_iter": "529", "eta": "0:00:12", "split": "test_iter", "time_diff": 0.30045}
# [11/28 09:06:50][INFO] logging.py:   99: json_stats: {"cur_iter": "530", "eta": "0:00:11", "split": "test_iter", "time_diff": 0.29241}
# [11/28 09:06:50][INFO] logging.py:   99: json_stats: {"cur_iter": "531", "eta": "0:00:11", "split": "test_iter", "time_diff": 0.30098}
# [11/28 09:06:50][INFO] logging.py:   99: json_stats: {"cur_iter": "532", "eta": "0:00:11", "split": "test_iter", "time_diff": 0.29262}
# [11/28 09:06:50][INFO] logging.py:   99: json_stats: {"cur_iter": "533", "eta": "0:00:11", "split": "test_iter", "time_diff": 0.30219}
# [11/28 09:06:51][INFO] logging.py:   99: json_stats: {"cur_iter": "534", "eta": "0:00:10", "split": "test_iter", "time_diff": 0.29542}
# [11/28 09:06:51][INFO] logging.py:   99: json_stats: {"cur_iter": "535", "eta": "0:00:10", "split": "test_iter", "time_diff": 0.30182}
# [11/28 09:06:51][INFO] logging.py:   99: json_stats: {"cur_iter": "536", "eta": "0:00:10", "split": "test_iter", "time_diff": 0.29670}
# [11/28 09:06:52][INFO] logging.py:   99: json_stats: {"cur_iter": "537", "eta": "0:00:10", "split": "test_iter", "time_diff": 0.30341}
# [11/28 09:06:52][INFO] logging.py:   99: json_stats: {"cur_iter": "538", "eta": "0:00:09", "split": "test_iter", "time_diff": 0.29948}
# [11/28 09:06:52][INFO] logging.py:   99: json_stats: {"cur_iter": "539", "eta": "0:00:09", "split": "test_iter", "time_diff": 0.30248}
# [11/28 09:06:53][INFO] logging.py:   99: json_stats: {"cur_iter": "540", "eta": "0:00:08", "split": "test_iter", "time_diff": 0.29400}
# [11/28 09:06:53][INFO] logging.py:   99: json_stats: {"cur_iter": "541", "eta": "0:00:08", "split": "test_iter", "time_diff": 0.29933}
# [11/28 09:06:53][INFO] logging.py:   99: json_stats: {"cur_iter": "542", "eta": "0:00:08", "split": "test_iter", "time_diff": 0.29575}
# [11/28 09:06:53][INFO] logging.py:   99: json_stats: {"cur_iter": "543", "eta": "0:00:08", "split": "test_iter", "time_diff": 0.29969}
# [11/28 09:06:54][INFO] logging.py:   99: json_stats: {"cur_iter": "544", "eta": "0:00:07", "split": "test_iter", "time_diff": 0.29626}
# [11/28 09:06:54][INFO] logging.py:   99: json_stats: {"cur_iter": "545", "eta": "0:00:07", "split": "test_iter", "time_diff": 0.29975}
# [11/28 09:06:54][INFO] logging.py:   99: json_stats: {"cur_iter": "546", "eta": "0:00:07", "split": "test_iter", "time_diff": 0.29623}
# [11/28 09:06:55][INFO] logging.py:   99: json_stats: {"cur_iter": "547", "eta": "0:00:06", "split": "test_iter", "time_diff": 0.30090}
# [11/28 09:06:55][INFO] logging.py:   99: json_stats: {"cur_iter": "548", "eta": "0:00:06", "split": "test_iter", "time_diff": 0.30181}
# [11/28 09:06:55][INFO] logging.py:   99: json_stats: {"cur_iter": "549", "eta": "0:00:06", "split": "test_iter", "time_diff": 0.30222}
# [11/28 09:06:56][INFO] logging.py:   99: json_stats: {"cur_iter": "550", "eta": "0:00:05", "split": "test_iter", "time_diff": 0.29353}
# [11/28 09:06:56][INFO] logging.py:   99: json_stats: {"cur_iter": "551", "eta": "0:00:05", "split": "test_iter", "time_diff": 0.30750}
# [11/28 09:06:56][INFO] logging.py:   99: json_stats: {"cur_iter": "552", "eta": "0:00:05", "split": "test_iter", "time_diff": 0.30238}
# [11/28 09:06:57][INFO] logging.py:   99: json_stats: {"cur_iter": "553", "eta": "0:00:05", "split": "test_iter", "time_diff": 0.30180}
# [11/28 09:06:57][INFO] logging.py:   99: json_stats: {"cur_iter": "554", "eta": "0:00:04", "split": "test_iter", "time_diff": 0.29813}
# [11/28 09:06:57][INFO] logging.py:   99: json_stats: {"cur_iter": "555", "eta": "0:00:04", "split": "test_iter", "time_diff": 0.29645}
# [11/28 09:06:57][INFO] logging.py:   99: json_stats: {"cur_iter": "556", "eta": "0:00:04", "split": "test_iter", "time_diff": 0.30136}
# [11/28 09:06:58][INFO] logging.py:   99: json_stats: {"cur_iter": "557", "eta": "0:00:03", "split": "test_iter", "time_diff": 0.29166}
# [11/28 09:06:58][INFO] logging.py:   99: json_stats: {"cur_iter": "558", "eta": "0:00:03", "split": "test_iter", "time_diff": 0.29464}
# [11/28 09:06:58][INFO] logging.py:   99: json_stats: {"cur_iter": "559", "eta": "0:00:03", "split": "test_iter", "time_diff": 0.30170}
# [11/28 09:06:59][INFO] logging.py:   99: json_stats: {"cur_iter": "560", "eta": "0:00:03", "split": "test_iter", "time_diff": 0.30048}
# [11/28 09:06:59][INFO] logging.py:   99: json_stats: {"cur_iter": "561", "eta": "0:00:03", "split": "test_iter", "time_diff": 0.33627}
# [11/28 09:06:59][INFO] logging.py:   99: json_stats: {"cur_iter": "562", "eta": "0:00:02", "split": "test_iter", "time_diff": 0.29124}
# [11/28 09:07:00][INFO] logging.py:   99: json_stats: {"cur_iter": "563", "eta": "0:00:02", "split": "test_iter", "time_diff": 0.29851}
# [11/28 09:07:00][INFO] logging.py:   99: json_stats: {"cur_iter": "564", "eta": "0:00:01", "split": "test_iter", "time_diff": 0.30018}
# [11/28 09:07:00][INFO] logging.py:   99: json_stats: {"cur_iter": "565", "eta": "0:00:01", "split": "test_iter", "time_diff": 0.30008}
# [11/28 09:07:00][INFO] logging.py:   99: json_stats: {"cur_iter": "566", "eta": "0:00:01", "split": "test_iter", "time_diff": 0.29984}
# [11/28 09:07:01][INFO] logging.py:   99: json_stats: {"cur_iter": "567", "eta": "0:00:00", "split": "test_iter", "time_diff": 0.29362}
# [11/28 09:07:01][INFO] logging.py:   99: json_stats: {"cur_iter": "568", "eta": "0:00:00", "split": "test_iter", "time_diff": 0.29042}
# [11/28 09:07:01][INFO] logging.py:   99: json_stats: {"cur_iter": "569", "eta": "0:00:00", "split": "test_iter", "time_diff": 0.05299}
# [11/28 09:07:02][INFO] test_net.py:  158: Successfully saved prediction results to ./output1.pkl
# [11/28 09:07:02][INFO] logging.py:   99: json_stats: {"split": "test_final", "top1_acc": "5.28", "top5_acc": "66.01"}
# [11/28 09:07:02][INFO] test_net.py:  262: Finalized testing with 10 temporal clips and 3 spatial crops
# [11/28 09:07:02][INFO] test_net.py:  282: _p39.01_f88.60_10a5.28 Top5 Acc: 66.01 MEM: 3.74 f: 88.6021
# [11/28 09:07:02][INFO] test_net.py:  283: _p39.01_f88.60_10a5.28

# %% [markdown]
# **The predictions are saved in output1.pkl file in the project directory.**

# %%
import pickle
with open("output1.pkl", "rb") as f:
    out = pickle.load(f)

# %%
import numpy as np

output_np = np.argmax(out[0][:], axis=1)

# %%
result_mod = ["predictions"] + output_np.numpy().tolist()
np.savetxt("submission.csv", np.array(result_mod),  fmt='%s')
