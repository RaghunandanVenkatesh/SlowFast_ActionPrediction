# %% [markdown]
# For the video action recognition, we are using [**PySlowFast**](https://github.com/facebookresearch/SlowFast) from Facebook Research.
#
# The goal of PySlowFast is to provide a high-performance, light-weight pytorch codebase provides state-of-the-art video backbones for video understanding research on different tasks (classification, detection, and etc). It is designed in order to support rapid implementation and evaluation of novel video research ideas. PySlowFast includes implementations of the following backbone network architectures:
#
# - SlowFast
# - Slow
# - C2D
# - I3D
# - Non-local Network
# - X3D
# - MViTv1 and MViTv2
# - Rev-ViT and Rev-MViT
#
#
# We used SLOW network architecture for this competetion

# %% [markdown]
# We have done modifications required to the model and source code and created our own github repo. The link is [**here**](https://github.com/RaghunandanVenkatesh/SlowFast/tree/dphi).
#
#
# The required python module installations and dataset preparation is followed from the PySlowfast official github repo.
#
# The detailed explaination of custom dataset preparation can be seen [here](https://github.com/facebookresearch/SlowFast/issues/149#issuecomment-723265461)

# %% [markdown]
# PySlowfast project gives a lot of flexible features for training and testing, including saving the checkpoints, auto resume training, augmenting dataset, testing with a check point, write predictions to a text file. Each of these features are controlled using YAML files.
#
# The model parameters and custom configuration are written in Yaml files and added to our repository
#
# - Training Configuration [YAML](https://github.com/RaghunandanVenkatesh/SlowFast/blob/dphi/configs/MyData/SLOW_NLN_8x8_R50-Train.yaml)
# - Testing Configuration [YAML](https://github.com/RaghunandanVenkatesh/SlowFast/blob/dphi/configs/MyData/SLOW_NLN_8x8_R50-Test.yaml)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["CUDA_LAUNCH_BLOCKING"]="1"

# %% [markdown]
# !git clone https://github.com/RaghunandanVenkatesh/SlowFast

# %% [markdown]
# Follow installation instructions here [INSTALL.md](https://github.com/facebookresearch/SlowFast/blob/main/INSTALL.md)

# %%
% cd Slowfast

# %% [markdown]
# **Training on the dataset**

# %%
# !python tools/run_net.py --cfg configs/MyData/SLOW_NLN_8x8_R50-Train.yaml
# Out:
# /opt/conda/lib/python3.7/site-packages/torchvision/transforms/_functional_video.py:7: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   "The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. "
# /opt/conda/lib/python3.7/site-packages/torchvision/transforms/_transforms_video.py:23: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   "The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. "
# config files: ['configs/MyData/SLOW_NLN_8x8_R50.yaml']
# [11/24 11:30:39][INFO] test_net.py:  190: Test with config:
# [11/24 11:30:39][INFO] test_net.py:  191: AUG:
#   AA_TYPE: rand-m9-mstd0.5-inc1
#   COLOR_JITTER: 0.4
#   ENABLE: False
#   GEN_MASK_LOADER: False
#   INTERPOLATION: bicubic
#   MASK_FRAMES: False
#   MASK_RATIO: 0.0
#   MASK_TUBE: False
#   MASK_WINDOW_SIZE: [8, 7, 7]
#   MAX_MASK_PATCHES_PER_BLOCK: None
#   NUM_SAMPLE: 1
#   RE_COUNT: 1
#   RE_MODE: pixel
#   RE_PROB: 0.25
#   RE_SPLIT: False
# AVA:
#   ANNOTATION_DIR: /mnt/vol/gfsai-flash3-east/ai-group/users/haoqifan/ava/frame_list/
#   BGR: False
#   DETECTION_SCORE_THRESH: 0.9
#   EXCLUSION_FILE: ava_val_excluded_timestamps_v2.2.csv
#   FRAME_DIR: /mnt/fair-flash3-east/ava_trainval_frames.img/
#   FRAME_LIST_DIR: /mnt/vol/gfsai-flash3-east/ai-group/users/haoqifan/ava/frame_list/
#   FULL_TEST_ON_VAL: False
#   GROUNDTRUTH_FILE: ava_val_v2.2.csv
#   IMG_PROC_BACKEND: cv2
#   LABEL_MAP_FILE: ava_action_list_v2.2_for_activitynet_2019.pbtxt
#   TEST_FORCE_FLIP: False
#   TEST_LISTS: ['val.csv']
#   TEST_PREDICT_BOX_LISTS: ['ava_val_predicted_boxes.csv']
#   TRAIN_GT_BOX_LISTS: ['ava_train_v2.2.csv']
#   TRAIN_LISTS: ['train.csv']
#   TRAIN_PCA_JITTER_ONLY: True
#   TRAIN_PREDICT_BOX_LISTS: []
#   TRAIN_USE_COLOR_AUGMENTATION: False
# BENCHMARK:
#   LOG_PERIOD: 100
#   NUM_EPOCHS: 5
#   SHUFFLE: True
# BN:
#   GLOBAL_SYNC: False
#   NORM_TYPE: batchnorm
#   NUM_BATCHES_PRECISE: 200
#   NUM_SPLITS: 1
#   NUM_SYNC_DEVICES: 1
#   USE_PRECISE_STATS: True
#   WEIGHT_DECAY: 0.0
# CONTRASTIVE:
#   BN_MLP: False
#   BN_SYNC_MLP: False
#   DELTA_CLIPS_MAX: inf
#   DELTA_CLIPS_MIN: -inf
#   DIM: 128
#   INTERP_MEMORY: False
#   KNN_ON: True
#   LENGTH: 239975
#   LOCAL_SHUFFLE_BN: True
#   MEM_TYPE: 1d
#   MLP_DIM: 2048
#   MOCO_MULTI_VIEW_QUEUE: False
#   MOMENTUM: 0.5
#   MOMENTUM_ANNEALING: False
#   NUM_CLASSES_DOWNSTREAM: 13
#   NUM_MLP_LAYERS: 1
#   PREDICTOR_DEPTHS: []
#   QUEUE_LEN: 65536
#   SEQUENTIAL: False
#   SIMCLR_DIST_ON: True
#   SWAV_QEUE_LEN: 0
#   T: 0.07
#   TYPE: mem
# DATA:
#   COLOR_RND_GRAYSCALE: 0.0
#   DECODING_BACKEND: pyav
#   DECODING_SHORT_SIZE: 256
#   DUMMY_LOAD: False
#   ENSEMBLE_METHOD: sum
#   IN22K_TRAINVAL: False
#   IN22k_VAL_IN1K:
#   INPUT_CHANNEL_NUM: [3]
#   INV_UNIFORM_SAMPLE: False
#   IN_VAL_CROP_RATIO: 0.875
#   LOADER_CHUNK_OVERALL_SIZE: 0
#   LOADER_CHUNK_SIZE: 0
#   MEAN: [0.45, 0.45, 0.45]
#   MULTI_LABEL: False
#   NUM_FRAMES: 8
#   PATH_LABEL_SEPARATOR:
#   PATH_PREFIX:
#   PATH_TO_DATA_DIR: /workspace/slowfast/data/MyData
#   PATH_TO_PRELOAD_IMDB:
#   RANDOM_FLIP: True
#   REVERSE_INPUT_CHANNEL: False
#   SAMPLING_RATE: 8
#   SKIP_ROWS: 0
#   SSL_BLUR_SIGMA_MAX: [0.0, 2.0]
#   SSL_BLUR_SIGMA_MIN: [0.0, 0.1]
#   SSL_COLOR_BRI_CON_SAT: [0.4, 0.4, 0.4]
#   SSL_COLOR_HUE: 0.1
#   SSL_COLOR_JITTER: False
#   SSL_MOCOV2_AUG: False
#   STD: [0.225, 0.225, 0.225]
#   TARGET_FPS: 30
#   TEST_CROP_SIZE: 256
#   TIME_DIFF_PROB: 0.0
#   TRAIN_CROP_NUM_SPATIAL: 1
#   TRAIN_CROP_NUM_TEMPORAL: 1
#   TRAIN_CROP_SIZE: 224
#   TRAIN_JITTER_ASPECT_RELATIVE: []
#   TRAIN_JITTER_FPS: 0.0
#   TRAIN_JITTER_MOTION_SHIFT: False
#   TRAIN_JITTER_SCALES: [256, 320]
#   TRAIN_JITTER_SCALES_RELATIVE: []
#   TRAIN_PCA_EIGVAL: [0.225, 0.224, 0.229]
#   TRAIN_PCA_EIGVEC: [[-0.5675, 0.7192, 0.4009], [-0.5808, -0.0045, -0.814], [-0.5836, -0.6948, 0.4203]]
#   USE_OFFSET_SAMPLING: False
# DATA_LOADER:
#   ENABLE_MULTI_THREAD_DECODE: False
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# DEMO:
#   BUFFER_SIZE: 0
#   CLIP_VIS_SIZE: 10
#   COMMON_CLASS_NAMES: ['watch (a person)', 'talk to (e.g., self, a person, a group)', 'listen to (a person)', 'touch (an object)', 'carry/hold (an object)', 'walk', 'sit', 'lie/sleep', 'bend/bow (at the waist)']
#   COMMON_CLASS_THRES: 0.25
#   DETECTRON2_CFG: COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml
#   DETECTRON2_THRESH: 0.9
#   DETECTRON2_WEIGHTS: detectron2://COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl
#   DISPLAY_HEIGHT: 0
#   DISPLAY_WIDTH: 0
#   ENABLE: False
#   FPS: 30
#   GT_BOXES:
#   INPUT_FORMAT: BGR
#   INPUT_VIDEO: /workspace/slowfast/data/MyData/Abuse/Abuse001_x264.mp4
#   LABEL_FILE_PATH: /workspace/slowfast/data/MyData/classids.json
#   NUM_CLIPS_SKIP: 0
#   NUM_VIS_INSTANCES: 2
#   OUTPUT_FILE: /workspace/slowfast/data/MyData/output.mp4
#   OUTPUT_FPS: -1
#   PREDS_BOXES:
#   SLOWMO: 1
#   STARTING_SECOND: 900
#   THREAD_ENABLE: False
#   UNCOMMON_CLASS_THRES: 0.3
#   VIS_MODE: thres
#   WEBCAM: -1
# DETECTION:
#   ALIGNED: True
#   ENABLE: False
#   ROI_XFORM_RESOLUTION: 7
#   SPATIAL_SCALE_FACTOR: 16
# DIST_BACKEND: nccl
# LOG_MODEL_INFO: True
# LOG_PERIOD: 10
# MASK:
#   DECODER_DEPTH: 0
#   DECODER_EMBED_DIM: 512
#   DECODER_SEP_POS_EMBED: False
#   DEC_KV_KERNEL: []
#   DEC_KV_STRIDE: []
#   ENABLE: False
#   HEAD_TYPE: separate
#   MAE_ON: False
#   MAE_RND_MASK: False
#   NORM_PRED_PIXEL: True
#   PER_FRAME_MASKING: False
#   PRED_HOG: False
#   PRETRAIN_DEPTH: [15]
#   SCALE_INIT_BY_DEPTH: False
#   TIME_STRIDE_LOSS: True
# MIXUP:
#   ALPHA: 0.8
#   CUTMIX_ALPHA: 1.0
#   ENABLE: False
#   LABEL_SMOOTH_VALUE: 0.1
#   PROB: 1.0
#   SWITCH_PROB: 0.5
# MODEL:
#   ACT_CHECKPOINT: False
#   ARCH: slow
#   DETACH_FINAL_FC: False
#   DROPCONNECT_RATE: 0.0
#   DROPOUT_RATE: 0.5
#   FC_INIT_STD: 0.01
#   FP16_ALLREDUCE: False
#   FROZEN_BN: False
#   HEAD_ACT: softmax
#   LOSS_FUNC: cross_entropy
#   MODEL_NAME: ResNet
#   MULTI_PATHWAY_ARCH: ['slowfast']
#   NUM_CLASSES: 13
#   SINGLE_PATHWAY_ARCH: ['2d', 'c2d', 'i3d', 'slow', 'x3d', 'mvit', 'maskmvit']
# MULTIGRID:
#   BN_BASE_SIZE: 8
#   DEFAULT_B: 0
#   DEFAULT_S: 0
#   DEFAULT_T: 0
#   EPOCH_FACTOR: 1.5
#   EVAL_FREQ: 3
#   LONG_CYCLE: False
#   LONG_CYCLE_FACTORS: [(0.25, 0.7071067811865476), (0.5, 0.7071067811865476), (0.5, 1), (1, 1)]
#   LONG_CYCLE_SAMPLING_RATE: 0
#   SHORT_CYCLE: False
#   SHORT_CYCLE_FACTORS: [0.5, 0.7071067811865476]
# MVIT:
#   CLS_EMBED_ON: True
#   DEPTH: 16
#   DIM_MUL: []
#   DIM_MUL_IN_ATT: False
#   DROPOUT_RATE: 0.0
#   DROPPATH_RATE: 0.1
#   EMBED_DIM: 96
#   HEAD_INIT_SCALE: 1.0
#   HEAD_MUL: []
#   LAYER_SCALE_INIT_VALUE: 0.0
#   MLP_RATIO: 4.0
#   MODE: conv
#   NORM: layernorm
#   NORM_STEM: False
#   NUM_HEADS: 1
#   PATCH_2D: False
#   PATCH_KERNEL: [3, 7, 7]
#   PATCH_PADDING: [2, 4, 4]
#   PATCH_STRIDE: [2, 4, 4]
#   POOL_FIRST: False
#   POOL_KVQ_KERNEL: None
#   POOL_KV_STRIDE: []
#   POOL_KV_STRIDE_ADAPTIVE: None
#   POOL_Q_STRIDE: []
#   QKV_BIAS: True
#   REL_POS_SPATIAL: False
#   REL_POS_TEMPORAL: False
#   REL_POS_ZERO_INIT: False
#   RESIDUAL_POOLING: False
#   REV:
#     BUFFER_LAYERS: []
#     ENABLE: False
#     PRE_Q_FUSION: avg
#     RESPATH_FUSE: concat
#     RES_PATH: conv
#   SEPARATE_QKV: False
#   SEP_POS_EMBED: False
#   USE_ABS_POS: True
#   USE_FIXED_SINCOS_POS: False
#   USE_MEAN_POOLING: False
#   ZERO_DECAY_POS_CLS: True
# NONLOCAL:
#   GROUP: [[1], [1], [1], [1]]
#   INSTANTIATION: dot_product
#   LOCATION: [[[]], [[1, 3]], [[1, 3, 5]], [[]]]
#   POOL: [[[1, 2, 2], [1, 2, 2]], [[1, 2, 2], [1, 2, 2]], [[1, 2, 2], [1, 2, 2]], [[1, 2, 2], [1, 2, 2]]]
# NUM_GPUS: 1
# NUM_SHARDS: 1
# OUTPUT_DIR: .
# RESNET:
#   DEPTH: 50
#   INPLACE_RELU: True
#   NUM_BLOCK_TEMP_KERNEL: [[3], [4], [6], [3]]
#   NUM_GROUPS: 1
#   SPATIAL_DILATIONS: [[1], [1], [1], [1]]
#   SPATIAL_STRIDES: [[1], [2], [2], [2]]
#   STRIDE_1X1: False
#   TRANS_FUNC: bottleneck_transform
#   WIDTH_PER_GROUP: 64
#   ZERO_INIT_FINAL_BN: True
#   ZERO_INIT_FINAL_CONV: False
# RNG_SEED: 0
# SHARD_ID: 0
# SLOWFAST:
#   ALPHA: 8
#   BETA_INV: 8
#   FUSION_CONV_CHANNEL_RATIO: 2
#   FUSION_KERNEL_SZ: 5
# SOLVER:
#   BASE_LR: 0.1
#   BASE_LR_SCALE_NUM_SHARDS: False
#   BETAS: (0.9, 0.999)
#   CLIP_GRAD_L2NORM: None
#   CLIP_GRAD_VAL: None
#   COSINE_AFTER_WARMUP: False
#   COSINE_END_LR: 0.0
#   DAMPENING: 0.0
#   GAMMA: 0.1
#   LARS_ON: False
#   LAYER_DECAY: 1.0
#   LRS: []
#   LR_POLICY: cosine
#   MAX_EPOCH: 200
#   MOMENTUM: 0.9
#   NESTEROV: True
#   OPTIMIZING_METHOD: sgd
#   STEPS: []
#   STEP_SIZE: 1
#   WARMUP_EPOCHS: 34.0
#   WARMUP_FACTOR: 0.1
#   WARMUP_START_LR: 0.01
#   WEIGHT_DECAY: 0.0001
#   ZERO_WD_1D_PARAM: False
# TASK:
# TENSORBOARD:
#   CATEGORIES_PATH:
#   CLASS_NAMES_PATH: /workspace/slowfast/data/MyData/classids.json
#   CONFUSION_MATRIX:
#     ENABLE: True
#     FIGSIZE: [8, 8]
#     SUBSET_PATH: /workspace/slowfast/data/MyData/class_names.txt
#   ENABLE: True
#   HISTOGRAM:
#     ENABLE: True
#     FIGSIZE: [8, 8]
#     SUBSET_PATH:
#     TOPK: 10
#   LOG_DIR:
#   MODEL_VIS:
#     ACTIVATIONS: False
#     COLORMAP: Pastel2
#     ENABLE: False
#     GRAD_CAM:
#       COLORMAP: viridis
#       ENABLE: True
#       LAYER_LIST: []
#       USE_TRUE_LABEL: False
#     INPUT_VIDEO: False
#     LAYER_LIST: []
#     MODEL_WEIGHTS: False
#     TOPK_PREDS: 1
#   PREDICTIONS_PATH:
#   WRONG_PRED_VIS:
#     ENABLE: False
#     SUBSET_PATH:
#     TAG: Incorrectly classified videos.
# TEST:
#   BATCH_SIZE: 16
#   CHECKPOINT_FILE_PATH: /workspace/slowfast/checkpoints/checkpoint_epoch_00160.pyth
#   CHECKPOINT_TYPE: pytorch
#   DATASET: mydata
#   ENABLE: True
#   NUM_ENSEMBLE_VIEWS: 10
#   NUM_SPATIAL_CROPS: 3
#   NUM_TEMPORAL_CLIPS: [10]
#   SAVE_RESULTS_PATH: output1.pkl
# TRAIN:
#   AUTO_RESUME: True
#   BATCH_SIZE: 16
#   CHECKPOINT_CLEAR_NAME_PATTERN: ()
#   CHECKPOINT_EPOCH_RESET: False
#   CHECKPOINT_FILE_PATH:
#   CHECKPOINT_INFLATE: False
#   CHECKPOINT_IN_INIT: False
#   CHECKPOINT_PERIOD: 1
#   CHECKPOINT_TYPE: pytorch
#   DATASET: mydata
#   ENABLE: False
#   EVAL_PERIOD: 10
#   KILL_LOSS_EXPLOSION_FACTOR: 0.0
#   MIXED_PRECISION: False
# VIS_MASK:
#   ENABLE: False
# X3D:
#   BN_LIN5: False
#   BOTTLENECK_FACTOR: 1.0
#   CHANNELWISE_3x3x3: True
#   DEPTH_FACTOR: 1.0
#   DIM_C1: 12
#   DIM_C5: 2048
#   SCALE_RES2: False
#   WIDTH_FACTOR: 1.0
# [11/24 11:30:41][INFO] misc.py:  185: Model:
# ResNet(
#   (s1): VideoModelStem(
#     (pathway0_stem): ResNetBasicStem(
#       (conv): Conv3d(3, 64, kernel_size=(1, 7, 7), stride=(1, 2, 2), padding=(0, 3, 3), bias=False)
#       (bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (pool_layer): MaxPool3d(kernel_size=[1, 3, 3], stride=[1, 2, 2], padding=[0, 1, 1], dilation=1, ceil_mode=False)
#     )
#   )
#   (s2): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (branch1_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (pathway0_pool): MaxPool3d(kernel_size=[1, 1, 1], stride=[1, 1, 1], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#   (s3): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal1): Nonlocal(
#       (conv_theta): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res3): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal3): Nonlocal(
#       (conv_theta): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#   )
#   (s4): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal1): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res3): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal3): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res4): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res5): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal5): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#   )
#   (s5): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (head): ResNetBasicHead(
#     (predictors): ModuleList()
#     (pathway0_avgpool): AvgPool3d(kernel_size=[8, 7, 7], stride=1, padding=0)
#     (dropout): Dropout(p=0.5, inplace=False)
#     (projection): Linear(in_features=2048, out_features=13, bias=True)
#     (act): Softmax(dim=4)
#   )
# )
# [11/24 11:30:41][INFO] misc.py:  187: Params: 39,019,597
# [11/24 11:30:41][INFO] misc.py:  188: Mem: 0.14659929275512695 MB
# [11/24 11:30:42][WARNING] jit_analysis.py:  500: Unsupported operator aten::max_pool3d encountered 7 time(s)
# [11/24 11:30:42][WARNING] jit_analysis.py:  500: Unsupported operator aten::add encountered 21 time(s)
# [11/24 11:30:42][WARNING] jit_analysis.py:  500: Unsupported operator aten::div encountered 5 time(s)
# [11/24 11:30:42][WARNING] jit_analysis.py:  500: Unsupported operator aten::avg_pool3d encountered 1 time(s)
# [11/24 11:30:42][WARNING] jit_analysis.py:  500: Unsupported operator aten::softmax encountered 1 time(s)
# [11/24 11:30:42][WARNING] jit_analysis.py:  500: Unsupported operator aten::mean encountered 1 time(s)
# [11/24 11:30:42][INFO] misc.py:  190: Flops: 88.602157056 G
# [11/24 11:30:42][WARNING] jit_analysis.py:  500: Unsupported operator aten::batch_norm encountered 58 time(s)
# [11/24 11:30:42][WARNING] jit_analysis.py:  500: Unsupported operator aten::max_pool3d encountered 7 time(s)
# [11/24 11:30:42][WARNING] jit_analysis.py:  500: Unsupported operator aten::add encountered 21 time(s)
# [11/24 11:30:42][WARNING] jit_analysis.py:  500: Unsupported operator aten::div encountered 5 time(s)
# [11/24 11:30:42][WARNING] jit_analysis.py:  500: Unsupported operator aten::avg_pool3d encountered 1 time(s)
# [11/24 11:30:42][WARNING] jit_analysis.py:  500: Unsupported operator aten::softmax encountered 1 time(s)
# [11/24 11:30:42][WARNING] jit_analysis.py:  500: Unsupported operator aten::mean encountered 1 time(s)
# [11/24 11:30:42][INFO] misc.py:  193: Activations: 185.860148 M
# [11/24 11:30:42][INFO] misc.py:  196: nvidia-smi
# Thu Nov 24 11:30:43 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.141.03   Driver Version: 470.141.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A10G         Off  | 00000000:00:1E.0 Off |                    0 |
# |  0%   17C    P0    62W / 300W |   3027MiB / 22731MiB |     11%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# [11/24 11:30:43][INFO] misc.py:  185: Model:
# ResNet(
#   (s1): VideoModelStem(
#     (pathway0_stem): ResNetBasicStem(
#       (conv): Conv3d(3, 64, kernel_size=(1, 7, 7), stride=(1, 2, 2), padding=(0, 3, 3), bias=False)
#       (bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (pool_layer): MaxPool3d(kernel_size=[1, 3, 3], stride=[1, 2, 2], padding=[0, 1, 1], dilation=1, ceil_mode=False)
#     )
#   )
#   (s2): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#       (branch1_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (pathway0_pool): MaxPool3d(kernel_size=[1, 1, 1], stride=[1, 1, 1], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#   (s3): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal1): Nonlocal(
#       (conv_theta): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res3): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (a_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal3): Nonlocal(
#       (conv_theta): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#   )
#   (s4): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(512, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal1): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res3): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal3): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#     (pathway0_res4): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res5): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_nonlocal5): Nonlocal(
#       (conv_theta): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_phi): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_g): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (conv_out): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#       (bn): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (pool): MaxPool3d(kernel_size=[1, 2, 2], stride=[1, 2, 2], padding=[0, 0, 0], dilation=1, ceil_mode=False)
#     )
#   )
#   (s5): ResStage(
#     (pathway0_res0): ResBlock(
#       (branch1): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#       (branch1_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (branch2): BottleneckTransform(
#         (a): Conv3d(1024, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res1): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (pathway0_res2): ResBlock(
#       (branch2): BottleneckTransform(
#         (a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         (a_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#         (b_bn): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (b_relu): ReLU(inplace=True)
#         (c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         (c_bn): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (head): ResNetBasicHead(
#     (predictors): ModuleList()
#     (pathway0_avgpool): AvgPool3d(kernel_size=[8, 7, 7], stride=1, padding=0)
#     (dropout): Dropout(p=0.5, inplace=False)
#     (projection): Linear(in_features=2048, out_features=13, bias=True)
#     (act): Softmax(dim=4)
#   )
# )
# [11/24 11:30:43][INFO] misc.py:  187: Params: 39,019,597
# [11/24 11:30:43][INFO] misc.py:  188: Mem: 1.5986194610595703 MB
# [11/24 11:30:43][WARNING] jit_analysis.py:  500: Unsupported operator aten::max_pool3d encountered 7 time(s)
# [11/24 11:30:43][WARNING] jit_analysis.py:  500: Unsupported operator aten::add encountered 21 time(s)
# [11/24 11:30:43][WARNING] jit_analysis.py:  500: Unsupported operator aten::div encountered 5 time(s)
# [11/24 11:30:43][WARNING] jit_analysis.py:  500: Unsupported operator aten::avg_pool3d encountered 1 time(s)
# [11/24 11:30:43][WARNING] jit_analysis.py:  500: Unsupported operator aten::softmax encountered 1 time(s)
# [11/24 11:30:43][WARNING] jit_analysis.py:  500: Unsupported operator aten::mean encountered 1 time(s)
# [11/24 11:30:43][INFO] misc.py:  190: Flops: 88.602157056 G
# [11/24 11:30:43][WARNING] jit_analysis.py:  500: Unsupported operator aten::batch_norm encountered 58 time(s)
# [11/24 11:30:43][WARNING] jit_analysis.py:  500: Unsupported operator aten::max_pool3d encountered 7 time(s)
# [11/24 11:30:43][WARNING] jit_analysis.py:  500: Unsupported operator aten::add encountered 21 time(s)
# [11/24 11:30:43][WARNING] jit_analysis.py:  500: Unsupported operator aten::div encountered 5 time(s)
# [11/24 11:30:43][WARNING] jit_analysis.py:  500: Unsupported operator aten::avg_pool3d encountered 1 time(s)
# [11/24 11:30:43][WARNING] jit_analysis.py:  500: Unsupported operator aten::softmax encountered 1 time(s)
# [11/24 11:30:43][WARNING] jit_analysis.py:  500: Unsupported operator aten::mean encountered 1 time(s)
# ...
# [11/24 11:33:02][INFO] logging.py:   99: json_stats: {"cur_iter": "456", "eta": "0:00:33", "split": "test_iter", "time_diff": 0.29490}
# [11/24 11:33:02][INFO] logging.py:   99: json_stats: {"cur_iter": "457", "eta": "0:00:33", "split": "test_iter", "time_diff": 0.29927}
# [11/24 11:33:03][INFO] logging.py:   99: json_stats: {"cur_iter": "458", "eta": "0:00:33", "split": "test_iter", "time_diff": 0.29663}
# [11/24 11:33:03][INFO] logging.py:   99: json_stats: {"cur_iter": "459", "eta": "0:00:33", "split": "test_iter", "time_diff": 0.30109}
# [11/24 11:33:03][INFO] logging.py:   99: json_stats: {"cur_iter": "460", "eta": "0:00:32", "split": "test_iter", "time_diff": 0.29515}
# [11/24 11:33:04][INFO] logging.py:   99: json_stats: {"cur_iter": "461", "eta": "0:00:32", "split": "test_iter", "time_diff": 0.30047}
# [11/24 11:33:04][INFO] logging.py:   99: json_stats: {"cur_iter": "462", "eta": "0:00:31", "split": "test_iter", "time_diff": 0.29523}
# [11/24 11:33:04][INFO] logging.py:   99: json_stats: {"cur_iter": "463", "eta": "0:00:32", "split": "test_iter", "time_diff": 0.30089}
# [11/24 11:33:04][INFO] logging.py:   99: json_stats: {"cur_iter": "464", "eta": "0:00:32", "split": "test_iter", "time_diff": 0.30297}
# [11/24 11:33:05][INFO] logging.py:   99: json_stats: {"cur_iter": "465", "eta": "0:00:31", "split": "test_iter", "time_diff": 0.30243}
# [11/24 11:33:05][INFO] logging.py:   99: json_stats: {"cur_iter": "466", "eta": "0:00:31", "split": "test_iter", "time_diff": 0.30442}
# [11/24 11:33:05][INFO] logging.py:   99: json_stats: {"cur_iter": "467", "eta": "0:00:31", "split": "test_iter", "time_diff": 0.30328}
# [11/24 11:33:06][INFO] logging.py:   99: json_stats: {"cur_iter": "468", "eta": "0:00:30", "split": "test_iter", "time_diff": 0.29795}
# [11/24 11:33:06][INFO] logging.py:   99: json_stats: {"cur_iter": "469", "eta": "0:00:30", "split": "test_iter", "time_diff": 0.29993}
# [11/24 11:33:06][INFO] logging.py:   99: json_stats: {"cur_iter": "470", "eta": "0:00:29", "split": "test_iter", "time_diff": 0.29676}
# [11/24 11:33:07][INFO] logging.py:   99: json_stats: {"cur_iter": "471", "eta": "0:00:29", "split": "test_iter", "time_diff": 0.30158}
# [11/24 11:33:07][INFO] logging.py:   99: json_stats: {"cur_iter": "472", "eta": "0:00:29", "split": "test_iter", "time_diff": 0.29860}
# [11/24 11:33:07][INFO] logging.py:   99: json_stats: {"cur_iter": "473", "eta": "0:00:29", "split": "test_iter", "time_diff": 0.30010}
# [11/24 11:33:08][INFO] logging.py:   99: json_stats: {"cur_iter": "474", "eta": "0:00:28", "split": "test_iter", "time_diff": 0.29615}
# [11/24 11:33:08][INFO] logging.py:   99: json_stats: {"cur_iter": "475", "eta": "0:00:28", "split": "test_iter", "time_diff": 0.30080}
# [11/24 11:33:08][INFO] logging.py:   99: json_stats: {"cur_iter": "476", "eta": "0:00:27", "split": "test_iter", "time_diff": 0.29552}
# [11/24 11:33:08][INFO] logging.py:   99: json_stats: {"cur_iter": "477", "eta": "0:00:27", "split": "test_iter", "time_diff": 0.29870}
# [11/24 11:33:09][INFO] logging.py:   99: json_stats: {"cur_iter": "478", "eta": "0:00:27", "split": "test_iter", "time_diff": 0.30186}
# [11/24 11:33:09][INFO] logging.py:   99: json_stats: {"cur_iter": "479", "eta": "0:00:27", "split": "test_iter", "time_diff": 0.30198}
# [11/24 11:33:09][INFO] logging.py:   99: json_stats: {"cur_iter": "480", "eta": "0:00:26", "split": "test_iter", "time_diff": 0.29855}
# [11/24 11:33:10][INFO] logging.py:   99: json_stats: {"cur_iter": "481", "eta": "0:00:26", "split": "test_iter", "time_diff": 0.29925}
# [11/24 11:33:10][INFO] logging.py:   99: json_stats: {"cur_iter": "482", "eta": "0:00:25", "split": "test_iter", "time_diff": 0.29519}
# [11/24 11:33:10][INFO] logging.py:   99: json_stats: {"cur_iter": "483", "eta": "0:00:26", "split": "test_iter", "time_diff": 0.30245}
# [11/24 11:33:11][INFO] logging.py:   99: json_stats: {"cur_iter": "484", "eta": "0:00:25", "split": "test_iter", "time_diff": 0.29665}
# [11/24 11:33:11][INFO] logging.py:   99: json_stats: {"cur_iter": "485", "eta": "0:00:25", "split": "test_iter", "time_diff": 0.30083}
# [11/24 11:33:11][INFO] logging.py:   99: json_stats: {"cur_iter": "486", "eta": "0:00:24", "split": "test_iter", "time_diff": 0.29531}
# [11/24 11:33:11][INFO] logging.py:   99: json_stats: {"cur_iter": "487", "eta": "0:00:24", "split": "test_iter", "time_diff": 0.29944}
# [11/24 11:33:12][INFO] logging.py:   99: json_stats: {"cur_iter": "488", "eta": "0:00:24", "split": "test_iter", "time_diff": 0.30195}
# [11/24 11:33:12][INFO] logging.py:   99: json_stats: {"cur_iter": "489", "eta": "0:00:24", "split": "test_iter", "time_diff": 0.30307}
# [11/24 11:33:12][INFO] logging.py:   99: json_stats: {"cur_iter": "490", "eta": "0:00:23", "split": "test_iter", "time_diff": 0.29358}
# [11/24 11:33:13][INFO] logging.py:   99: json_stats: {"cur_iter": "491", "eta": "0:00:23", "split": "test_iter", "time_diff": 0.29201}
# [11/24 11:33:13][INFO] logging.py:   99: json_stats: {"cur_iter": "492", "eta": "0:00:23", "split": "test_iter", "time_diff": 0.30171}
# [11/24 11:33:13][INFO] logging.py:   99: json_stats: {"cur_iter": "493", "eta": "0:00:23", "split": "test_iter", "time_diff": 0.30024}
# [11/24 11:33:14][INFO] logging.py:   99: json_stats: {"cur_iter": "494", "eta": "0:00:22", "split": "test_iter", "time_diff": 0.29522}
# [11/24 11:33:14][INFO] logging.py:   99: json_stats: {"cur_iter": "495", "eta": "0:00:22", "split": "test_iter", "time_diff": 0.29987}
# [11/24 11:33:14][INFO] logging.py:   99: json_stats: {"cur_iter": "496", "eta": "0:00:22", "split": "test_iter", "time_diff": 0.30152}
# [11/24 11:33:14][INFO] logging.py:   99: json_stats: {"cur_iter": "497", "eta": "0:00:21", "split": "test_iter", "time_diff": 0.29673}
# [11/24 11:33:15][INFO] logging.py:   99: json_stats: {"cur_iter": "498", "eta": "0:00:21", "split": "test_iter", "time_diff": 0.29193}
# [11/24 11:33:15][INFO] logging.py:   99: json_stats: {"cur_iter": "499", "eta": "0:00:21", "split": "test_iter", "time_diff": 0.29851}
# [11/24 11:33:15][INFO] logging.py:   99: json_stats: {"cur_iter": "500", "eta": "0:00:20", "split": "test_iter", "time_diff": 0.29487}
# [11/24 11:33:16][INFO] logging.py:   99: json_stats: {"cur_iter": "501", "eta": "0:00:20", "split": "test_iter", "time_diff": 0.29928}
# [11/24 11:33:16][INFO] logging.py:   99: json_stats: {"cur_iter": "502", "eta": "0:00:20", "split": "test_iter", "time_diff": 0.29638}
# [11/24 11:33:16][INFO] logging.py:   99: json_stats: {"cur_iter": "503", "eta": "0:00:20", "split": "test_iter", "time_diff": 0.29983}
# [11/24 11:33:16][INFO] logging.py:   99: json_stats: {"cur_iter": "504", "eta": "0:00:19", "split": "test_iter", "time_diff": 0.29888}
# [11/24 11:33:17][INFO] logging.py:   99: json_stats: {"cur_iter": "505", "eta": "0:00:19", "split": "test_iter", "time_diff": 0.29958}
# [11/24 11:33:17][INFO] logging.py:   99: json_stats: {"cur_iter": "506", "eta": "0:00:19", "split": "test_iter", "time_diff": 0.29820}
# [11/24 11:33:17][INFO] logging.py:   99: json_stats: {"cur_iter": "507", "eta": "0:00:18", "split": "test_iter", "time_diff": 0.30118}
# [11/24 11:33:18][INFO] logging.py:   99: json_stats: {"cur_iter": "508", "eta": "0:00:18", "split": "test_iter", "time_diff": 0.29700}
# [11/24 11:33:18][INFO] logging.py:   99: json_stats: {"cur_iter": "509", "eta": "0:00:18", "split": "test_iter", "time_diff": 0.29927}
# [11/24 11:33:18][INFO] logging.py:   99: json_stats: {"cur_iter": "510", "eta": "0:00:17", "split": "test_iter", "time_diff": 0.29551}
# [11/24 11:33:19][INFO] logging.py:   99: json_stats: {"cur_iter": "511", "eta": "0:00:17", "split": "test_iter", "time_diff": 0.30103}
# [11/24 11:33:19][INFO] logging.py:   99: json_stats: {"cur_iter": "512", "eta": "0:00:17", "split": "test_iter", "time_diff": 0.29500}
# [11/24 11:33:19][INFO] logging.py:   99: json_stats: {"cur_iter": "513", "eta": "0:00:17", "split": "test_iter", "time_diff": 0.29911}
# [11/24 11:33:19][INFO] logging.py:   99: json_stats: {"cur_iter": "514", "eta": "0:00:16", "split": "test_iter", "time_diff": 0.29344}
# [11/24 11:33:20][INFO] logging.py:   99: json_stats: {"cur_iter": "515", "eta": "0:00:16", "split": "test_iter", "time_diff": 0.29848}
# [11/24 11:33:20][INFO] logging.py:   99: json_stats: {"cur_iter": "516", "eta": "0:00:15", "split": "test_iter", "time_diff": 0.29573}
# [11/24 11:33:20][INFO] logging.py:   99: json_stats: {"cur_iter": "517", "eta": "0:00:15", "split": "test_iter", "time_diff": 0.29952}
# [11/24 11:33:21][INFO] logging.py:   99: json_stats: {"cur_iter": "518", "eta": "0:00:15", "split": "test_iter", "time_diff": 0.29551}
# [11/24 11:33:21][INFO] logging.py:   99: json_stats: {"cur_iter": "519", "eta": "0:00:15", "split": "test_iter", "time_diff": 0.30270}
# [11/24 11:33:21][INFO] logging.py:   99: json_stats: {"cur_iter": "520", "eta": "0:00:14", "split": "test_iter", "time_diff": 0.29230}
# [11/24 11:33:22][INFO] logging.py:   99: json_stats: {"cur_iter": "521", "eta": "0:00:14", "split": "test_iter", "time_diff": 0.30103}
# [11/24 11:33:22][INFO] logging.py:   99: json_stats: {"cur_iter": "522", "eta": "0:00:14", "split": "test_iter", "time_diff": 0.29362}
# [11/24 11:33:22][INFO] logging.py:   99: json_stats: {"cur_iter": "523", "eta": "0:00:14", "split": "test_iter", "time_diff": 0.29905}
# [11/24 11:33:22][INFO] logging.py:   99: json_stats: {"cur_iter": "524", "eta": "0:00:13", "split": "test_iter", "time_diff": 0.29881}
# [11/24 11:33:23][INFO] logging.py:   99: json_stats: {"cur_iter": "525", "eta": "0:00:13", "split": "test_iter", "time_diff": 0.30086}
# [11/24 11:33:23][INFO] logging.py:   99: json_stats: {"cur_iter": "526", "eta": "0:00:13", "split": "test_iter", "time_diff": 0.30274}
# [11/24 11:33:23][INFO] logging.py:   99: json_stats: {"cur_iter": "527", "eta": "0:00:12", "split": "test_iter", "time_diff": 0.29787}
# [11/24 11:33:24][INFO] logging.py:   99: json_stats: {"cur_iter": "528", "eta": "0:00:12", "split": "test_iter", "time_diff": 0.29151}
# [11/24 11:33:24][INFO] logging.py:   99: json_stats: {"cur_iter": "529", "eta": "0:00:12", "split": "test_iter", "time_diff": 0.29981}
# [11/24 11:33:24][INFO] logging.py:   99: json_stats: {"cur_iter": "530", "eta": "0:00:11", "split": "test_iter", "time_diff": 0.29896}
# [11/24 11:33:25][INFO] logging.py:   99: json_stats: {"cur_iter": "531", "eta": "0:00:11", "split": "test_iter", "time_diff": 0.30061}
# [11/24 11:33:25][INFO] logging.py:   99: json_stats: {"cur_iter": "532", "eta": "0:00:11", "split": "test_iter", "time_diff": 0.29645}
# [11/24 11:33:25][INFO] logging.py:   99: json_stats: {"cur_iter": "533", "eta": "0:00:11", "split": "test_iter", "time_diff": 0.29881}
# [11/24 11:33:25][INFO] logging.py:   99: json_stats: {"cur_iter": "534", "eta": "0:00:10", "split": "test_iter", "time_diff": 0.29140}
# [11/24 11:33:26][INFO] logging.py:   99: json_stats: {"cur_iter": "535", "eta": "0:00:10", "split": "test_iter", "time_diff": 0.30181}
# [11/24 11:33:26][INFO] logging.py:   99: json_stats: {"cur_iter": "536", "eta": "0:00:10", "split": "test_iter", "time_diff": 0.30314}
# [11/24 11:33:26][INFO] logging.py:   99: json_stats: {"cur_iter": "537", "eta": "0:00:09", "split": "test_iter", "time_diff": 0.30154}
# [11/24 11:33:27][INFO] logging.py:   99: json_stats: {"cur_iter": "538", "eta": "0:00:09", "split": "test_iter", "time_diff": 0.29058}
# [11/24 11:33:27][INFO] logging.py:   99: json_stats: {"cur_iter": "539", "eta": "0:00:09", "split": "test_iter", "time_diff": 0.30169}
# [11/24 11:33:27][INFO] logging.py:   99: json_stats: {"cur_iter": "540", "eta": "0:00:08", "split": "test_iter", "time_diff": 0.29629}
# [11/24 11:33:28][INFO] logging.py:   99: json_stats: {"cur_iter": "541", "eta": "0:00:08", "split": "test_iter", "time_diff": 0.29996}
# [11/24 11:33:28][INFO] logging.py:   99: json_stats: {"cur_iter": "542", "eta": "0:00:08", "split": "test_iter", "time_diff": 0.29425}
# [11/24 11:33:28][INFO] logging.py:   99: json_stats: {"cur_iter": "543", "eta": "0:00:08", "split": "test_iter", "time_diff": 0.30130}
# [11/24 11:33:28][INFO] logging.py:   99: json_stats: {"cur_iter": "544", "eta": "0:00:07", "split": "test_iter", "time_diff": 0.29786}
# [11/24 11:33:29][INFO] logging.py:   99: json_stats: {"cur_iter": "545", "eta": "0:00:07", "split": "test_iter", "time_diff": 0.30100}
# [11/24 11:33:29][INFO] logging.py:   99: json_stats: {"cur_iter": "546", "eta": "0:00:07", "split": "test_iter", "time_diff": 0.30110}
# [11/24 11:33:29][INFO] logging.py:   99: json_stats: {"cur_iter": "547", "eta": "0:00:06", "split": "test_iter", "time_diff": 0.30102}
# [11/24 11:33:30][INFO] logging.py:   99: json_stats: {"cur_iter": "548", "eta": "0:00:06", "split": "test_iter", "time_diff": 0.29284}
# [11/24 11:33:30][INFO] logging.py:   99: json_stats: {"cur_iter": "549", "eta": "0:00:06", "split": "test_iter", "time_diff": 0.29840}
# [11/24 11:33:30][INFO] logging.py:   99: json_stats: {"cur_iter": "550", "eta": "0:00:06", "split": "test_iter", "time_diff": 0.30404}
# [11/24 11:33:31][INFO] logging.py:   99: json_stats: {"cur_iter": "551", "eta": "0:00:05", "split": "test_iter", "time_diff": 0.29600}
# [11/24 11:33:31][INFO] logging.py:   99: json_stats: {"cur_iter": "552", "eta": "0:00:05", "split": "test_iter", "time_diff": 0.29405}
# [11/24 11:33:31][INFO] logging.py:   99: json_stats: {"cur_iter": "553", "eta": "0:00:05", "split": "test_iter", "time_diff": 0.29917}
# [11/24 11:33:31][INFO] logging.py:   99: json_stats: {"cur_iter": "554", "eta": "0:00:04", "split": "test_iter", "time_diff": 0.30399}
# [11/24 11:33:32][INFO] logging.py:   99: json_stats: {"cur_iter": "555", "eta": "0:00:04", "split": "test_iter", "time_diff": 0.29842}
# [11/24 11:33:32][INFO] logging.py:   99: json_stats: {"cur_iter": "556", "eta": "0:00:04", "split": "test_iter", "time_diff": 0.29152}
# [11/24 11:33:32][INFO] logging.py:   99: json_stats: {"cur_iter": "557", "eta": "0:00:03", "split": "test_iter", "time_diff": 0.29936}
# [11/24 11:33:33][INFO] logging.py:   99: json_stats: {"cur_iter": "558", "eta": "0:00:03", "split": "test_iter", "time_diff": 0.30181}
# [11/24 11:33:33][INFO] logging.py:   99: json_stats: {"cur_iter": "559", "eta": "0:00:03", "split": "test_iter", "time_diff": 0.29961}
# [11/24 11:33:33][INFO] logging.py:   99: json_stats: {"cur_iter": "560", "eta": "0:00:02", "split": "test_iter", "time_diff": 0.29724}
# [11/24 11:33:34][INFO] logging.py:   99: json_stats: {"cur_iter": "561", "eta": "0:00:02", "split": "test_iter", "time_diff": 0.29424}
# [11/24 11:33:34][INFO] logging.py:   99: json_stats: {"cur_iter": "562", "eta": "0:00:02", "split": "test_iter", "time_diff": 0.29110}
# [11/24 11:33:34][INFO] logging.py:   99: json_stats: {"cur_iter": "563", "eta": "0:00:02", "split": "test_iter", "time_diff": 0.29204}
# [11/24 11:33:34][INFO] logging.py:   99: json_stats: {"cur_iter": "564", "eta": "0:00:01", "split": "test_iter", "time_diff": 0.29144}
# [11/24 11:33:35][INFO] logging.py:   99: json_stats: {"cur_iter": "565", "eta": "0:00:01", "split": "test_iter", "time_diff": 0.29103}
# [11/24 11:33:35][INFO] logging.py:   99: json_stats: {"cur_iter": "566", "eta": "0:00:01", "split": "test_iter", "time_diff": 0.29254}
# [11/24 11:33:35][INFO] logging.py:   99: json_stats: {"cur_iter": "567", "eta": "0:00:00", "split": "test_iter", "time_diff": 0.29031}
# [11/24 11:33:36][INFO] logging.py:   99: json_stats: {"cur_iter": "568", "eta": "0:00:00", "split": "test_iter", "time_diff": 0.29050}
# [11/24 11:33:36][INFO] logging.py:   99: json_stats: {"cur_iter": "569", "eta": "0:00:00", "split": "test_iter", "time_diff": 0.05311}
# [11/24 11:33:39][INFO] test_net.py:  158: Successfully saved prediction results to ./output1.pkl
# [11/24 11:33:39][INFO] logging.py:   99: json_stats: {"split": "test_final", "top1_acc": "1.32", "top5_acc": "35.31"}
# [11/24 11:33:39][INFO] test_net.py:  262: Finalized testing with 10 temporal clips and 3 spatial crops
# [11/24 11:33:39][INFO] test_net.py:  282: _p39.02_f88.60_10a1.32 Top5 Acc: 35.31 MEM: 3.74 f: 88.6022
# [11/24 11:33:39][INFO] test_net.py:  283: _p39.02_f88.60_10a1.32

# %% [markdown]
# **Testing**

# %%
# !python tools/run_net.py --cfg configs/MyData/SLOW_NLN_8x8_R50-Test.yaml

# %% [markdown]
# **The predictions are saved in output1.pkl file in the project directory.**

# %%
import pickle
with open("output1.pkl", "rb") as f:
    out = pickle.load(f)

# %%
import numpy as np

output_np = np.argmax(out[0][:], axis=1)

# %%
result_mod = ["predictions"] + output_np.numpy().tolist()
np.savetxt("submission.csv", np.array(result_mod),  fmt='%s')
